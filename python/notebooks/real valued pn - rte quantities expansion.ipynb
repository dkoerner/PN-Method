# %% [markdown]
# ------------------------------
#
# Expansion of the radiance field $L$ into real SH:
#
# ------------------------------
# $$
# \sum_{l=0}^{N}{\left(\sum_{m=-l}^{-1}{L^{{l,m}}\left (\vec{x} \right )\left(\frac{i}{\sqrt{2}}Y^{l, m}(\omega )-\frac{i}{\sqrt{2}}\left({-1}\right)^{m}Y^{l, -m}(\omega )\right)}+L^{{l,0}}\left (\vec{x} \right )Y^{l, 0}(\omega )+\sum_{m=1}^{l}{L^{{l,m}}\left (\vec{x} \right )\left(\frac{1}{\sqrt{2}}Y^{l, -m}(\omega )+\frac{1}{\sqrt{2}}\left({-1}\right)^{m}Y^{l, m}(\omega )\right)}\right)}
# $$
#
# ------------------------------
# $$
# \frac{i}{\sqrt{2}}\left(\sum_{l=0}^{N}{\sum_{m=-l}^{-1}{L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)-\frac{i}{\sqrt{2}}\left(\sum_{l=0}^{N}{\sum_{m=-l}^{-1}{L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}Y^{l, -m}(\omega )}}\right)+\sum_{l=0}^{N}{L^{{l,0}}\left (\vec{x} \right )Y^{l, 0}(\omega )}+\frac{1}{\sqrt{2}}\left(\sum_{l=0}^{N}{\sum_{m=1}^{l}{L^{{l,m}}\left (\vec{x} \right )Y^{l, -m}(\omega )}}\right)+\frac{1}{\sqrt{2}}\left(\sum_{l=0}^{N}{\sum_{m=1}^{l}{L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}Y^{l, m}(\omega )}}\right)
# $$

# %% [markdown]
# $$
# \omega_{x}\partial_xL\left (\vec{x} ,\omega \right )+\omega_{y}\partial_yL\left (\vec{x} ,\omega \right )+\omega_{z}\partial_zL\left (\vec{x} ,\omega \right )
# $$

# %% [markdown]
# ------------------------------
# $$
# \int{\left(\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\overline{Y^{l', m'}}(\omega )-\frac{i}{\sqrt{2}}\overline{Y^{l', -m'}}(\omega )\right)\left(\omega_{x}\partial_xL\left (\vec{x} ,\omega \right )+\omega_{y}\partial_yL\left (\vec{x} ,\omega \right )+\omega_{z}\partial_zL\left (\vec{x} ,\omega \right )\right)\mathbf{d}\omega}
# $$

# %% [markdown]
# ------------------------------
# $$
# \int{\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\overline{Y^{l', m'}}(\omega )\left(\omega_{x}\partial_xL\left (\vec{x} ,\omega \right )+\omega_{y}\partial_yL\left (\vec{x} ,\omega \right )+\omega_{z}\partial_zL\left (\vec{x} ,\omega \right )\right)+\left(-\frac{i}{\sqrt{2}}\overline{Y^{l', -m'}}(\omega )\right)\left(\omega_{x}\partial_xL\left (\vec{x} ,\omega \right )+\omega_{y}\partial_yL\left (\vec{x} ,\omega \right )+\omega_{z}\partial_zL\left (\vec{x} ,\omega \right )\right)\mathbf{d}\omega}
# $$

# %% [markdown]
# ------------------------------
# $$
# \int{\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\overline{Y^{l', m'}}(\omega )\omega_{x}\partial_xL\left (\vec{x} ,\omega \right )+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\overline{Y^{l', m'}}(\omega )\omega_{y}\partial_yL\left (\vec{x} ,\omega \right )+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\overline{Y^{l', m'}}(\omega )\omega_{z}\partial_zL\left (\vec{x} ,\omega \right )+\left(-\frac{i}{\sqrt{2}}\overline{Y^{l', -m'}}(\omega )\right)\omega_{x}\partial_xL\left (\vec{x} ,\omega \right )+\left(-\frac{i}{\sqrt{2}}\overline{Y^{l', -m'}}(\omega )\right)\omega_{y}\partial_yL\left (\vec{x} ,\omega \right )+\left(-\frac{i}{\sqrt{2}}\overline{Y^{l', -m'}}(\omega )\right)\omega_{z}\partial_zL\left (\vec{x} ,\omega \right )\mathbf{d}\omega}
# $$

# %% [markdown]
# ------------------------------
# $$
# \int{\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\overline{Y^{l', m'}}(\omega )\omega_{x}\partial_xL\left (\vec{x} ,\omega \right )+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\overline{Y^{l', m'}}(\omega )\omega_{y}\partial_yL\left (\vec{x} ,\omega \right )+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\overline{Y^{l', m'}}(\omega )\omega_{z}\partial_zL\left (\vec{x} ,\omega \right )-\frac{i}{\sqrt{2}}\overline{Y^{l', -m'}}(\omega )\omega_{x}\partial_xL\left (\vec{x} ,\omega \right )-\frac{i}{\sqrt{2}}\overline{Y^{l', -m'}}(\omega )\omega_{y}\partial_yL\left (\vec{x} ,\omega \right )-\frac{i}{\sqrt{2}}\overline{Y^{l', -m'}}(\omega )\omega_{z}\partial_zL\left (\vec{x} ,\omega \right )\mathbf{d}\omega}
# $$

# %% [markdown]
# ------------------------------
# $$
# \int{\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}\left(-c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )+d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )+e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )-f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\right)\partial_xL\left (\vec{x} ,\omega \right )+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}\left(c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )-d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )+e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )-f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\right)\partial_yL\left (\vec{x} ,\omega \right )+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\left(a^{{l'-1,m'}}\overline{Y^{l'-1, m'}}(\omega )+b^{{l'+1,m'}}\overline{Y^{l'+1, m'}}(\omega )\right)\partial_zL\left (\vec{x} ,\omega \right )-\frac{i}{\sqrt{2}}\frac{1}{2}\left(-c^{{l'-1,-m'-1}}\overline{Y^{l'-1, -m'-1}}(\omega )+d^{{l'+1,-m'-1}}\overline{Y^{l'+1, -m'-1}}(\omega )+e^{{l'-1,-m'+1}}\overline{Y^{l'-1, -m'+1}}(\omega )-f^{{l'+1,-m'+1}}\overline{Y^{l'+1, -m'+1}}(\omega )\right)\partial_xL\left (\vec{x} ,\omega \right )-\frac{i}{\sqrt{2}}\frac{i}{2}\left(c^{{l'-1,-m'-1}}\overline{Y^{l'-1, -m'-1}}(\omega )-d^{{l'+1,-m'-1}}\overline{Y^{l'+1, -m'-1}}(\omega )+e^{{l'-1,-m'+1}}\overline{Y^{l'-1, -m'+1}}(\omega )-f^{{l'+1,-m'+1}}\overline{Y^{l'+1, -m'+1}}(\omega )\right)\partial_yL\left (\vec{x} ,\omega \right )-\frac{i}{\sqrt{2}}\left(a^{{l'-1,-m'}}\overline{Y^{l'-1, -m'}}(\omega )+b^{{l'+1,-m'}}\overline{Y^{l'+1, -m'}}(\omega )\right)\partial_zL\left (\vec{x} ,\omega \right )\mathbf{d}\omega}
# $$

# %% [markdown]
# ------------------------------
# $$
# \int{\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )\left(-c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )\right)+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )\left(-f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\right)+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )\left(-d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )\right)+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )\left(-f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\right)+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\partial_zL\left (\vec{x} ,\omega \right )a^{{l'-1,m'}}\overline{Y^{l'-1, m'}}(\omega )+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\partial_zL\left (\vec{x} ,\omega \right )b^{{l'+1,m'}}\overline{Y^{l'+1, m'}}(\omega )-\left(\frac{i}{\sqrt{2}}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )\left(-c^{{l'-1,-m'-1}}\overline{Y^{l'-1, -m'-1}}(\omega )\right)+\frac{i}{\sqrt{2}}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )d^{{l'+1,-m'-1}}\overline{Y^{l'+1, -m'-1}}(\omega )+\frac{i}{\sqrt{2}}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )e^{{l'-1,-m'+1}}\overline{Y^{l'-1, -m'+1}}(\omega )+\frac{i}{\sqrt{2}}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )\left(-f^{{l'+1,-m'+1}}\overline{Y^{l'+1, -m'+1}}(\omega )\right)\right)-\left(\frac{i}{\sqrt{2}}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )c^{{l'-1,-m'-1}}\overline{Y^{l'-1, -m'-1}}(\omega )+\frac{i}{\sqrt{2}}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )\left(-d^{{l'+1,-m'-1}}\overline{Y^{l'+1, -m'-1}}(\omega )\right)+\frac{i}{\sqrt{2}}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )e^{{l'-1,-m'+1}}\overline{Y^{l'-1, -m'+1}}(\omega )+\frac{i}{\sqrt{2}}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )\left(-f^{{l'+1,-m'+1}}\overline{Y^{l'+1, -m'+1}}(\omega )\right)\right)-\left(\frac{i}{\sqrt{2}}\partial_zL\left (\vec{x} ,\omega \right )a^{{l'-1,-m'}}\overline{Y^{l'-1, -m'}}(\omega )+\frac{i}{\sqrt{2}}\partial_zL\left (\vec{x} ,\omega \right )b^{{l'+1,-m'}}\overline{Y^{l'+1, -m'}}(\omega )\right)\mathbf{d}\omega}
# $$

# %% [markdown]
# ------------------------------
# $$
# \int{-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\partial_zL\left (\vec{x} ,\omega \right )a^{{l'-1,m'}}\overline{Y^{l'-1, m'}}(\omega )+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\partial_zL\left (\vec{x} ,\omega \right )b^{{l'+1,m'}}\overline{Y^{l'+1, m'}}(\omega )+\frac{i}{\sqrt{2}}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )c^{{l'-1,-m'-1}}\overline{Y^{l'-1, -m'-1}}(\omega )-\frac{i}{\sqrt{2}}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )d^{{l'+1,-m'-1}}\overline{Y^{l'+1, -m'-1}}(\omega )-\frac{i}{\sqrt{2}}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )e^{{l'-1,-m'+1}}\overline{Y^{l'-1, -m'+1}}(\omega )+\frac{i}{\sqrt{2}}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )f^{{l'+1,-m'+1}}\overline{Y^{l'+1, -m'+1}}(\omega )-\frac{i}{\sqrt{2}}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )c^{{l'-1,-m'-1}}\overline{Y^{l'-1, -m'-1}}(\omega )+\frac{i}{\sqrt{2}}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )d^{{l'+1,-m'-1}}\overline{Y^{l'+1, -m'-1}}(\omega )-\frac{i}{\sqrt{2}}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )e^{{l'-1,-m'+1}}\overline{Y^{l'-1, -m'+1}}(\omega )+\frac{i}{\sqrt{2}}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )f^{{l'+1,-m'+1}}\overline{Y^{l'+1, -m'+1}}(\omega )-\frac{i}{\sqrt{2}}\partial_zL\left (\vec{x} ,\omega \right )a^{{l'-1,-m'}}\overline{Y^{l'-1, -m'}}(\omega )-\frac{i}{\sqrt{2}}\partial_zL\left (\vec{x} ,\omega \right )b^{{l'+1,-m'}}\overline{Y^{l'+1, -m'}}(\omega )\mathbf{d}\omega}
# $$

# %% [markdown]
# ------------------------------
# $$
# \int{-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )\mathbf{d}\omega}+\int{-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}+\int{-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )\mathbf{d}\omega}+\int{-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\partial_zL\left (\vec{x} ,\omega \right )a^{{l'-1,m'}}\overline{Y^{l'-1, m'}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\partial_zL\left (\vec{x} ,\omega \right )b^{{l'+1,m'}}\overline{Y^{l'+1, m'}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{\sqrt{2}}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )c^{{l'-1,-m'-1}}\overline{Y^{l'-1, -m'-1}}(\omega )\mathbf{d}\omega}+\int{-\frac{i}{\sqrt{2}}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )d^{{l'+1,-m'-1}}\overline{Y^{l'+1, -m'-1}}(\omega )\mathbf{d}\omega}+\int{-\frac{i}{\sqrt{2}}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )e^{{l'-1,-m'+1}}\overline{Y^{l'-1, -m'+1}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{\sqrt{2}}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )f^{{l'+1,-m'+1}}\overline{Y^{l'+1, -m'+1}}(\omega )\mathbf{d}\omega}+\int{-\frac{i}{\sqrt{2}}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )c^{{l'-1,-m'-1}}\overline{Y^{l'-1, -m'-1}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{\sqrt{2}}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )d^{{l'+1,-m'-1}}\overline{Y^{l'+1, -m'-1}}(\omega )\mathbf{d}\omega}+\int{-\frac{i}{\sqrt{2}}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )e^{{l'-1,-m'+1}}\overline{Y^{l'-1, -m'+1}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{\sqrt{2}}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )f^{{l'+1,-m'+1}}\overline{Y^{l'+1, -m'+1}}(\omega )\mathbf{d}\omega}+\int{-\frac{i}{\sqrt{2}}\partial_zL\left (\vec{x} ,\omega \right )a^{{l'-1,-m'}}\overline{Y^{l'-1, -m'}}(\omega )\mathbf{d}\omega}+\int{-\frac{i}{\sqrt{2}}\partial_zL\left (\vec{x} ,\omega \right )b^{{l'+1,-m'}}\overline{Y^{l'+1, -m'}}(\omega )\mathbf{d}\omega}
# $$

# %% [markdown]
# ------------------------------
# $$
# -\int{\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )\mathbf{d}\omega}-\int{\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}-\int{\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )\mathbf{d}\omega}-\int{\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\partial_zL\left (\vec{x} ,\omega \right )a^{{l'-1,m'}}\overline{Y^{l'-1, m'}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\partial_zL\left (\vec{x} ,\omega \right )b^{{l'+1,m'}}\overline{Y^{l'+1, m'}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{\sqrt{2}}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )c^{{l'-1,-m'-1}}\overline{Y^{l'-1, -m'-1}}(\omega )\mathbf{d}\omega}-\int{\frac{i}{\sqrt{2}}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )d^{{l'+1,-m'-1}}\overline{Y^{l'+1, -m'-1}}(\omega )\mathbf{d}\omega}-\int{\frac{i}{\sqrt{2}}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )e^{{l'-1,-m'+1}}\overline{Y^{l'-1, -m'+1}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{\sqrt{2}}\frac{1}{2}\partial_xL\left (\vec{x} ,\omega \right )f^{{l'+1,-m'+1}}\overline{Y^{l'+1, -m'+1}}(\omega )\mathbf{d}\omega}-\int{\frac{i}{\sqrt{2}}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )c^{{l'-1,-m'-1}}\overline{Y^{l'-1, -m'-1}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{\sqrt{2}}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )d^{{l'+1,-m'-1}}\overline{Y^{l'+1, -m'-1}}(\omega )\mathbf{d}\omega}-\int{\frac{i}{\sqrt{2}}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )e^{{l'-1,-m'+1}}\overline{Y^{l'-1, -m'+1}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{\sqrt{2}}\frac{i}{2}\partial_yL\left (\vec{x} ,\omega \right )f^{{l'+1,-m'+1}}\overline{Y^{l'+1, -m'+1}}(\omega )\mathbf{d}\omega}-\int{\frac{i}{\sqrt{2}}\partial_zL\left (\vec{x} ,\omega \right )a^{{l'-1,-m'}}\overline{Y^{l'-1, -m'}}(\omega )\mathbf{d}\omega}-\int{\frac{i}{\sqrt{2}}\partial_zL\left (\vec{x} ,\omega \right )b^{{l'+1,-m'}}\overline{Y^{l'+1, -m'}}(\omega )\mathbf{d}\omega}
# $$

# %% [markdown]
# ------------------------------
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\int{\partial_xL\left (\vec{x} ,\omega \right )\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}d^{{l'+1,m'-1}}\int{\partial_xL\left (\vec{x} ,\omega \right )\overline{Y^{l'+1, m'-1}}(\omega )\mathbf{d}\omega}+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}e^{{l'-1,m'+1}}\int{\partial_xL\left (\vec{x} ,\omega \right )\overline{Y^{l'-1, m'+1}}(\omega )\mathbf{d}\omega}-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}f^{{l'+1,m'+1}}\int{\partial_xL\left (\vec{x} ,\omega \right )\overline{Y^{l'+1, m'+1}}(\omega )\mathbf{d}\omega}+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}c^{{l'-1,m'-1}}\int{\partial_yL\left (\vec{x} ,\omega \right )\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}d^{{l'+1,m'-1}}\int{\partial_yL\left (\vec{x} ,\omega \right )\overline{Y^{l'+1, m'-1}}(\omega )\mathbf{d}\omega}+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}e^{{l'-1,m'+1}}\int{\partial_yL\left (\vec{x} ,\omega \right )\overline{Y^{l'-1, m'+1}}(\omega )\mathbf{d}\omega}-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}f^{{l'+1,m'+1}}\int{\partial_yL\left (\vec{x} ,\omega \right )\overline{Y^{l'+1, m'+1}}(\omega )\mathbf{d}\omega}+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}a^{{l'-1,m'}}\int{\partial_zL\left (\vec{x} ,\omega \right )\overline{Y^{l'-1, m'}}(\omega )\mathbf{d}\omega}+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}b^{{l'+1,m'}}\int{\partial_zL\left (\vec{x} ,\omega \right )\overline{Y^{l'+1, m'}}(\omega )\mathbf{d}\omega}+\frac{i}{\sqrt{2}}\frac{1}{2}c^{{l'-1,-m'-1}}\int{\partial_xL\left (\vec{x} ,\omega \right )\overline{Y^{l'-1, -m'-1}}(\omega )\mathbf{d}\omega}-\frac{i}{\sqrt{2}}\frac{1}{2}d^{{l'+1,-m'-1}}\int{\partial_xL\left (\vec{x} ,\omega \right )\overline{Y^{l'+1, -m'-1}}(\omega )\mathbf{d}\omega}-\frac{i}{\sqrt{2}}\frac{1}{2}e^{{l'-1,-m'+1}}\int{\partial_xL\left (\vec{x} ,\omega \right )\overline{Y^{l'-1, -m'+1}}(\omega )\mathbf{d}\omega}+\frac{i}{\sqrt{2}}\frac{1}{2}f^{{l'+1,-m'+1}}\int{\partial_xL\left (\vec{x} ,\omega \right )\overline{Y^{l'+1, -m'+1}}(\omega )\mathbf{d}\omega}-\frac{i}{\sqrt{2}}\frac{i}{2}c^{{l'-1,-m'-1}}\int{\partial_yL\left (\vec{x} ,\omega \right )\overline{Y^{l'-1, -m'-1}}(\omega )\mathbf{d}\omega}+\frac{i}{\sqrt{2}}\frac{i}{2}d^{{l'+1,-m'-1}}\int{\partial_yL\left (\vec{x} ,\omega \right )\overline{Y^{l'+1, -m'-1}}(\omega )\mathbf{d}\omega}-\frac{i}{\sqrt{2}}\frac{i}{2}e^{{l'-1,-m'+1}}\int{\partial_yL\left (\vec{x} ,\omega \right )\overline{Y^{l'-1, -m'+1}}(\omega )\mathbf{d}\omega}+\frac{i}{\sqrt{2}}\frac{i}{2}f^{{l'+1,-m'+1}}\int{\partial_yL\left (\vec{x} ,\omega \right )\overline{Y^{l'+1, -m'+1}}(\omega )\mathbf{d}\omega}-\frac{i}{\sqrt{2}}a^{{l'-1,-m'}}\int{\partial_zL\left (\vec{x} ,\omega \right )\overline{Y^{l'-1, -m'}}(\omega )\mathbf{d}\omega}-\frac{i}{\sqrt{2}}b^{{l'+1,-m'}}\int{\partial_zL\left (\vec{x} ,\omega \right )\overline{Y^{l'+1, -m'}}(\omega )\mathbf{d}\omega}
# $$

# %% [markdown]
# ------------------------------
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\int{\partial_x\left(\frac{i}{\sqrt{2}}\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{-1}{L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}Y^{l, m}(\omega )}}\right)-\frac{i}{\sqrt{2}}\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{-1}{L^{{l,m}}\left (\vec{x} \right )Y^{l, -m}(\omega )}}\right)+\sum_{l=0}^{\infty}{L^{{l,0}}\left (\vec{x} \right )Y^{l, 0}(\omega )}+\frac{1}{\sqrt{2}}\left(\sum_{l=0}^{\infty}{\sum_{m=1}^{l}{L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}Y^{l, -m}(\omega )}}\right)+\frac{1}{\sqrt{2}}\left(\sum_{l=0}^{\infty}{\sum_{m=1}^{l}{L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\right)\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}
# $$

# %% [markdown]
# ------------------------------
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\int{\left(\partial_x\left(\frac{i}{\sqrt{2}}\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{-1}{L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}Y^{l, m}(\omega )}}\right)\right)+\partial_x\left(-\frac{i}{\sqrt{2}}\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{-1}{L^{{l,m}}\left (\vec{x} \right )Y^{l, -m}(\omega )}}\right)\right)+\partial_x\left(\sum_{l=0}^{\infty}{L^{{l,0}}\left (\vec{x} \right )Y^{l, 0}(\omega )}\right)+\partial_x\left(\frac{1}{\sqrt{2}}\left(\sum_{l=0}^{\infty}{\sum_{m=1}^{l}{L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}Y^{l, -m}(\omega )}}\right)\right)+\partial_x\left(\frac{1}{\sqrt{2}}\left(\sum_{l=0}^{\infty}{\sum_{m=1}^{l}{L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\right)\right)\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}
# $$

# %% [markdown]
# ------------------------------
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\int{\partial_x\left(\sum_{l=0}^{\infty}{\frac{i}{\sqrt{2}}\left(\sum_{m=-l}^{-1}{L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}Y^{l, m}(\omega )}\right)}\right)\overline{Y^{l'-1, m'-1}}(\omega )+\partial_x\left(-\sum_{l=0}^{\infty}{\frac{i}{\sqrt{2}}\left(\sum_{m=-l}^{-1}{L^{{l,m}}\left (\vec{x} \right )Y^{l, -m}(\omega )}\right)}\right)\overline{Y^{l'-1, m'-1}}(\omega )+\partial_x\left(\sum_{l=0}^{\infty}{L^{{l,0}}\left (\vec{x} \right )Y^{l, 0}(\omega )}\right)\overline{Y^{l'-1, m'-1}}(\omega )+\partial_x\left(\sum_{l=0}^{\infty}{\frac{1}{\sqrt{2}}\left(\sum_{m=1}^{l}{L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}Y^{l, -m}(\omega )}\right)}\right)\overline{Y^{l'-1, m'-1}}(\omega )+\partial_x\left(\sum_{l=0}^{\infty}{\frac{1}{\sqrt{2}}\left(\sum_{m=1}^{l}{L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)}\right)\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}
# $$
# |

# %% [markdown]
# ------------------------------
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\left(\int{\partial_x\left(\sum_{l=0}^{\infty}{\frac{i}{\sqrt{2}}\left(\sum_{m=-l}^{-1}{L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}Y^{l, m}(\omega )}\right)}\right)\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}+\int{\partial_x\left(-\sum_{l=0}^{\infty}{\frac{i}{\sqrt{2}}\left(\sum_{m=-l}^{-1}{L^{{l,m}}\left (\vec{x} \right )Y^{l, -m}(\omega )}\right)}\right)\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}+\int{\partial_x\left(\sum_{l=0}^{\infty}{L^{{l,0}}\left (\vec{x} \right )Y^{l, 0}(\omega )}\right)\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}+\int{\partial_x\left(\sum_{l=0}^{\infty}{\frac{1}{\sqrt{2}}\left(\sum_{m=1}^{l}{L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}Y^{l, -m}(\omega )}\right)}\right)\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}+\int{\partial_x\left(\sum_{l=0}^{\infty}{\frac{1}{\sqrt{2}}\left(\sum_{m=1}^{l}{L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)}\right)\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}\right)
# $$

# %% [markdown]
# ------------------------------
# $$
# -\left(\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\int{\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{-1}{\frac{i}{\sqrt{2}}L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}Y^{l, m}(\omega )}}\right)\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\int{\partial_x\left(-\sum_{l=0}^{\infty}{\sum_{m=-l}^{-1}{\frac{i}{\sqrt{2}}L^{{l,m}}\left (\vec{x} \right )Y^{l, -m}(\omega )}}\right)\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\int{\partial_x\left(\sum_{l=0}^{\infty}{L^{{l,0}}\left (\vec{x} \right )Y^{l, 0}(\omega )}\right)\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\int{\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=1}^{l}{\frac{1}{\sqrt{2}}L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}Y^{l, -m}(\omega )}}\right)\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\int{\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=1}^{l}{\frac{1}{\sqrt{2}}L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}\right)
# $$

# %% [markdown]
# ------------------------------
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\int{\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{-1}{\frac{i}{\sqrt{2}}L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}Y^{l, m}(\omega )}}\right)\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\int{\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{-1}{\frac{i}{\sqrt{2}}L^{{l,m}}\left (\vec{x} \right )Y^{l, -m}(\omega )}}\right)\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\int{\partial_x\left(\sum_{l=0}^{\infty}{L^{{l,0}}\left (\vec{x} \right )Y^{l, 0}(\omega )}\right)\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\int{\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=1}^{l}{\frac{1}{\sqrt{2}}L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}Y^{l, -m}(\omega )}}\right)\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\int{\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=1}^{l}{\frac{1}{\sqrt{2}}L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}
# $$

# %% [markdown]
# ------------------------------
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(\int{\overline{Y^{l'-1, m'-1}}(\omega )\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{-1}{\frac{i}{\sqrt{2}}L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}Y^{l, m}(\omega )}}\right)\mathbf{d}\omega}\right)+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(\int{\overline{Y^{l'-1, m'-1}}(\omega )\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{-1}{\frac{i}{\sqrt{2}}L^{{l,m}}\left (\vec{x} \right )Y^{l, -m}(\omega )}}\right)\mathbf{d}\omega}\right)-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(\int{\overline{Y^{l'-1, m'-1}}(\omega )\left(\sum_{l=0}^{\infty}{L^{{l,0}}\left (\vec{x} \right )Y^{l, 0}(\omega )}\right)\mathbf{d}\omega}\right)-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(\int{\overline{Y^{l'-1, m'-1}}(\omega )\left(\sum_{l=0}^{\infty}{\sum_{m=1}^{l}{\frac{1}{\sqrt{2}}L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}Y^{l, -m}(\omega )}}\right)\mathbf{d}\omega}\right)-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(\int{\overline{Y^{l'-1, m'-1}}(\omega )\left(\sum_{l=0}^{\infty}{\sum_{m=1}^{l}{\frac{1}{\sqrt{2}}L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\mathbf{d}\omega}\right)
# $$

# %% [markdown]
# ------------------------------
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(\sum_{l=0}^{\infty}{\int{\overline{Y^{l'-1, m'-1}}(\omega )\left(\sum_{m=-l}^{-1}{\frac{i}{\sqrt{2}}L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}Y^{l, m}(\omega )}\right)\mathbf{d}\omega}}\right)+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(\sum_{l=0}^{\infty}{\int{\overline{Y^{l'-1, m'-1}}(\omega )\left(\sum_{m=-l}^{-1}{\frac{i}{\sqrt{2}}L^{{l,m}}\left (\vec{x} \right )Y^{l, -m}(\omega )}\right)\mathbf{d}\omega}}\right)-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(\sum_{l=0}^{\infty}{\int{\overline{Y^{l'-1, m'-1}}(\omega )L^{{l,0}}\left (\vec{x} \right )Y^{l, 0}(\omega )\mathbf{d}\omega}}\right)-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(\sum_{l=0}^{\infty}{\int{\overline{Y^{l'-1, m'-1}}(\omega )\left(\sum_{m=1}^{l}{\frac{1}{\sqrt{2}}L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}Y^{l, -m}(\omega )}\right)\mathbf{d}\omega}}\right)-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(\sum_{l=0}^{\infty}{\int{\overline{Y^{l'-1, m'-1}}(\omega )\left(\sum_{m=1}^{l}{\frac{1}{\sqrt{2}}L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)\mathbf{d}\omega}}\right)
# $$

# %% [markdown]
# ------------------------------
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{-1}{\int{\overline{Y^{l'-1, m'-1}}(\omega )\frac{i}{\sqrt{2}}L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}Y^{l, m}(\omega )\mathbf{d}\omega}}}\right)+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{-1}{\int{\overline{Y^{l'-1, m'-1}}(\omega )\frac{i}{\sqrt{2}}L^{{l,m}}\left (\vec{x} \right )Y^{l, -m}(\omega )\mathbf{d}\omega}}}\right)-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(\sum_{l=0}^{\infty}{\int{\overline{Y^{l'-1, m'-1}}(\omega )L^{{l,0}}\left (\vec{x} \right )Y^{l, 0}(\omega )\mathbf{d}\omega}}\right)-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=1}^{l}{\int{\overline{Y^{l'-1, m'-1}}(\omega )\frac{1}{\sqrt{2}}L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}Y^{l, -m}(\omega )\mathbf{d}\omega}}}\right)-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=1}^{l}{\int{\overline{Y^{l'-1, m'-1}}(\omega )\frac{1}{\sqrt{2}}L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )\mathbf{d}\omega}}}\right)
# $$

# %% [markdown]
# ------------------------------
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\frac{i}{\sqrt{2}}\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{-1}{L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}\int{\overline{Y^{l'-1, m'-1}}(\omega )Y^{l, m}(\omega )\mathbf{d}\omega}}}\right)+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\frac{i}{\sqrt{2}}\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{-1}{L^{{l,m}}\left (\vec{x} \right )\int{\overline{Y^{l'-1, m'-1}}(\omega )Y^{l, -m}(\omega )\mathbf{d}\omega}}}\right)-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(\sum_{l=0}^{\infty}{L^{{l,0}}\left (\vec{x} \right )\int{\overline{Y^{l'-1, m'-1}}(\omega )Y^{l, 0}(\omega )\mathbf{d}\omega}}\right)-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\frac{1}{\sqrt{2}}\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=1}^{l}{L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}\int{\overline{Y^{l'-1, m'-1}}(\omega )Y^{l, -m}(\omega )\mathbf{d}\omega}}}\right)-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\frac{1}{\sqrt{2}}\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=1}^{l}{L^{{l,m}}\left (\vec{x} \right )\int{\overline{Y^{l'-1, m'-1}}(\omega )Y^{l, m}(\omega )\mathbf{d}\omega}}}\right)
# $$

# %% [markdown]
# ------------------------------
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\frac{i}{\sqrt{2}}\partial_x\left(\sum_{l=0}^{N}{\sum_{m=-l}^{-1}{L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}\delta_{l'-1,l}\delta_{m'-1,m}}}\right)+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\frac{i}{\sqrt{2}}\partial_x\left(\sum_{l=0}^{N}{\sum_{m=-l}^{-1}{L^{{l,m}}\left (\vec{x} \right )\delta_{l'-1,l}\delta_{m'-1,-m}}}\right)-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(\sum_{l=0}^{N}{L^{{l,0}}\left (\vec{x} \right )\delta_{l'-1,l}\delta_{m'-1,0}}\right)-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\frac{1}{\sqrt{2}}\partial_x\left(\sum_{l=0}^{N}{\sum_{m=1}^{l}{L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}\delta_{l'-1,l}\delta_{m'-1,-m}}}\right)-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\frac{1}{\sqrt{2}}\partial_x\left(\sum_{l=0}^{N}{\sum_{m=1}^{l}{L^{{l,m}}\left (\vec{x} \right )\delta_{l'-1,l}\delta_{m'-1,m}}}\right)
# $$
#
# ------------------------------
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\frac{i}{\sqrt{2}}\partial_x\left(\sum_{l=0}^{1}{\sum_{m=-l}^{-1}{L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}\delta_{l'-1,l}\delta_{m'-1,m}}}\right)+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\frac{i}{\sqrt{2}}\partial_x\left(\sum_{l=0}^{1}{\sum_{m=-l}^{-1}{L^{{l,m}}\left (\vec{x} \right )\delta_{l'-1,l}\delta_{m'-1,-m}}}\right)-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(\sum_{l=0}^{1}{L^{{l,0}}\left (\vec{x} \right )\delta_{l'-1,l}\delta_{m'-1,0}}\right)-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\frac{1}{\sqrt{2}}\partial_x\left(\sum_{l=0}^{1}{\sum_{m=1}^{l}{L^{{l,m}}\left (\vec{x} \right )\left({-1}\right)^{m}\delta_{l'-1,l}\delta_{m'-1,-m}}}\right)-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\frac{1}{\sqrt{2}}\partial_x\left(\sum_{l=0}^{1}{\sum_{m=1}^{l}{L^{{l,m}}\left (\vec{x} \right )\delta_{l'-1,l}\delta_{m'-1,m}}}\right)
# $$
#
# ------------------------------
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\frac{i}{\sqrt{2}}\partial_x\left(-L^{{1,-1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'-1,-1}\right)+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\frac{i}{\sqrt{2}}\partial_x\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'-1,1}\right)-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(L^{{0,0}}\left (\vec{x} \right )\delta_{l'-1,0}\delta_{m'-1,0}+L^{{1,0}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'-1,0}\right)-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\frac{1}{\sqrt{2}}\partial_x\left(-L^{{1,1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'-1,-1}\right)-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\frac{1}{\sqrt{2}}\partial_x\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'-1,1}\right)
# $$
#
# ------------------------------
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\frac{i}{\sqrt{2}}\partial_x\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'-1,-1}\right)+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\frac{i}{\sqrt{2}}\partial_x\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'-1,1}\right)-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(L^{{0,0}}\left (\vec{x} \right )\delta_{l'-1,0}\delta_{m'-1,0}+L^{{1,0}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'-1,0}\right)+\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\frac{1}{\sqrt{2}}\partial_x\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'-1,-1}\right)-\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\frac{1}{\sqrt{2}}\partial_x\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'-1,1}\right)
# $$

# %% [markdown]
# ------------------------------
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\frac{i}{\sqrt{2}}\partial_x\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'-1,-1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\frac{i}{\sqrt{2}}\partial_x\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'-1,1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(L^{{0,0}}\left (\vec{x} \right )\delta_{l'-1,0}\delta_{m'-1,0}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(L^{{1,0}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'-1,0}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\frac{1}{\sqrt{2}}\partial_x\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'-1,-1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}c^{{l'-1,m'-1}}\frac{1}{\sqrt{2}}\partial_x\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'-1,1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}d^{{l'+1,m'-1}}\frac{i}{\sqrt{2}}\partial_x\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{m'-1,-1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}d^{{l'+1,m'-1}}\frac{i}{\sqrt{2}}\partial_x\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{m'-1,1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}d^{{l'+1,m'-1}}\partial_x\left(L^{{0,0}}\left (\vec{x} \right )\delta_{l'+1,0}\delta_{m'-1,0}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}d^{{l'+1,m'-1}}\partial_x\left(L^{{1,0}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{m'-1,0}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}d^{{l'+1,m'-1}}\frac{1}{\sqrt{2}}\partial_x\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{m'-1,-1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}d^{{l'+1,m'-1}}\frac{1}{\sqrt{2}}\partial_x\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{m'-1,1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}e^{{l'-1,m'+1}}\frac{i}{\sqrt{2}}\partial_x\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'+1,-1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}e^{{l'-1,m'+1}}\frac{i}{\sqrt{2}}\partial_x\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'+1,1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}e^{{l'-1,m'+1}}\partial_x\left(L^{{0,0}}\left (\vec{x} \right )\delta_{l'-1,0}\delta_{m'+1,0}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}e^{{l'-1,m'+1}}\partial_x\left(L^{{1,0}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'+1,0}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}e^{{l'-1,m'+1}}\frac{1}{\sqrt{2}}\partial_x\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'+1,-1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}e^{{l'-1,m'+1}}\frac{1}{\sqrt{2}}\partial_x\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'+1,1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}f^{{l'+1,m'+1}}\frac{i}{\sqrt{2}}\partial_x\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{m'+1,-1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}f^{{l'+1,m'+1}}\frac{i}{\sqrt{2}}\partial_x\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{m'+1,1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}f^{{l'+1,m'+1}}\partial_x\left(L^{{0,0}}\left (\vec{x} \right )\delta_{l'+1,0}\delta_{m'+1,0}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}f^{{l'+1,m'+1}}\partial_x\left(L^{{1,0}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{m'+1,0}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}f^{{l'+1,m'+1}}\frac{1}{\sqrt{2}}\partial_x\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{m'+1,-1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{1}{2}f^{{l'+1,m'+1}}\frac{1}{\sqrt{2}}\partial_x\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{m'+1,1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}c^{{l'-1,m'-1}}\frac{i}{\sqrt{2}}\partial_y\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'-1,-1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}c^{{l'-1,m'-1}}\frac{i}{\sqrt{2}}\partial_y\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'-1,1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}c^{{l'-1,m'-1}}\partial_y\left(L^{{0,0}}\left (\vec{x} \right )\delta_{l'-1,0}\delta_{m'-1,0}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}c^{{l'-1,m'-1}}\partial_y\left(L^{{1,0}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'-1,0}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}c^{{l'-1,m'-1}}\frac{1}{\sqrt{2}}\partial_y\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'-1,-1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}c^{{l'-1,m'-1}}\frac{1}{\sqrt{2}}\partial_y\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'-1,1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}d^{{l'+1,m'-1}}\frac{i}{\sqrt{2}}\partial_y\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{m'-1,-1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}d^{{l'+1,m'-1}}\frac{i}{\sqrt{2}}\partial_y\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{m'-1,1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}d^{{l'+1,m'-1}}\partial_y\left(L^{{0,0}}\left (\vec{x} \right )\delta_{l'+1,0}\delta_{m'-1,0}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}d^{{l'+1,m'-1}}\partial_y\left(L^{{1,0}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{m'-1,0}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}d^{{l'+1,m'-1}}\frac{1}{\sqrt{2}}\partial_y\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{m'-1,-1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}d^{{l'+1,m'-1}}\frac{1}{\sqrt{2}}\partial_y\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{m'-1,1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}e^{{l'-1,m'+1}}\frac{i}{\sqrt{2}}\partial_y\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'+1,-1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}e^{{l'-1,m'+1}}\frac{i}{\sqrt{2}}\partial_y\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'+1,1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}e^{{l'-1,m'+1}}\partial_y\left(L^{{0,0}}\left (\vec{x} \right )\delta_{l'-1,0}\delta_{m'+1,0}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}e^{{l'-1,m'+1}}\partial_y\left(L^{{1,0}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'+1,0}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}e^{{l'-1,m'+1}}\frac{1}{\sqrt{2}}\partial_y\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'+1,-1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}e^{{l'-1,m'+1}}\frac{1}{\sqrt{2}}\partial_y\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m'+1,1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}f^{{l'+1,m'+1}}\frac{i}{\sqrt{2}}\partial_y\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{m'+1,-1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}f^{{l'+1,m'+1}}\frac{i}{\sqrt{2}}\partial_y\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{m'+1,1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}f^{{l'+1,m'+1}}\partial_y\left(L^{{0,0}}\left (\vec{x} \right )\delta_{l'+1,0}\delta_{m'+1,0}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}f^{{l'+1,m'+1}}\partial_y\left(L^{{1,0}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{m'+1,0}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}f^{{l'+1,m'+1}}\frac{1}{\sqrt{2}}\partial_y\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{m'+1,-1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}\frac{i}{2}f^{{l'+1,m'+1}}\frac{1}{\sqrt{2}}\partial_y\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{m'+1,1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}a^{{l'-1,m'}}\frac{i}{\sqrt{2}}\partial_z\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m',-1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}a^{{l'-1,m'}}\frac{i}{\sqrt{2}}\partial_z\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m',1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}a^{{l'-1,m'}}\partial_z\left(L^{{0,0}}\left (\vec{x} \right )\delta_{l'-1,0}\delta_{m',0}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}a^{{l'-1,m'}}\partial_z\left(L^{{1,0}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m',0}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}a^{{l'-1,m'}}\frac{1}{\sqrt{2}}\partial_z\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m',-1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}a^{{l'-1,m'}}\frac{1}{\sqrt{2}}\partial_z\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{m',1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}b^{{l'+1,m'}}\frac{i}{\sqrt{2}}\partial_z\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{m',-1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}b^{{l'+1,m'}}\frac{i}{\sqrt{2}}\partial_z\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{m',1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}b^{{l'+1,m'}}\partial_z\left(L^{{0,0}}\left (\vec{x} \right )\delta_{l'+1,0}\delta_{m',0}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}b^{{l'+1,m'}}\partial_z\left(L^{{1,0}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{m',0}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\left({-1}\right)^{m'}b^{{l'+1,m'}}\frac{1}{\sqrt{2}}\partial_z\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{m',-1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\left({-1}\right)^{m'}b^{{l'+1,m'}}\frac{1}{\sqrt{2}}\partial_z\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{m',1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\frac{1}{2}c^{{l'-1,-m'-1}}\frac{i}{\sqrt{2}}\partial_x\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{-m'-1,-1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\frac{1}{2}c^{{l'-1,-m'-1}}\frac{i}{\sqrt{2}}\partial_x\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{-m'-1,1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\frac{1}{2}c^{{l'-1,-m'-1}}\partial_x\left(L^{{0,0}}\left (\vec{x} \right )\delta_{l'-1,0}\delta_{-m'-1,0}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\frac{1}{2}c^{{l'-1,-m'-1}}\partial_x\left(L^{{1,0}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{-m'-1,0}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\frac{1}{2}c^{{l'-1,-m'-1}}\frac{1}{\sqrt{2}}\partial_x\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{-m'-1,-1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\frac{1}{2}c^{{l'-1,-m'-1}}\frac{1}{\sqrt{2}}\partial_x\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{-m'-1,1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\frac{1}{2}d^{{l'+1,-m'-1}}\frac{i}{\sqrt{2}}\partial_x\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{-m'-1,-1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\frac{1}{2}d^{{l'+1,-m'-1}}\frac{i}{\sqrt{2}}\partial_x\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{-m'-1,1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\frac{1}{2}d^{{l'+1,-m'-1}}\partial_x\left(L^{{0,0}}\left (\vec{x} \right )\delta_{l'+1,0}\delta_{-m'-1,0}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\frac{1}{2}d^{{l'+1,-m'-1}}\partial_x\left(L^{{1,0}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{-m'-1,0}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\frac{1}{2}d^{{l'+1,-m'-1}}\frac{1}{\sqrt{2}}\partial_x\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{-m'-1,-1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\frac{1}{2}d^{{l'+1,-m'-1}}\frac{1}{\sqrt{2}}\partial_x\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{-m'-1,1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\frac{1}{2}e^{{l'-1,-m'+1}}\frac{i}{\sqrt{2}}\partial_x\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{-m'+1,-1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\frac{1}{2}e^{{l'-1,-m'+1}}\frac{i}{\sqrt{2}}\partial_x\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{-m'+1,1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\frac{1}{2}e^{{l'-1,-m'+1}}\partial_x\left(L^{{0,0}}\left (\vec{x} \right )\delta_{l'-1,0}\delta_{-m'+1,0}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\frac{1}{2}e^{{l'-1,-m'+1}}\partial_x\left(L^{{1,0}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{-m'+1,0}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\frac{1}{2}e^{{l'-1,-m'+1}}\frac{1}{\sqrt{2}}\partial_x\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{-m'+1,-1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\frac{1}{2}e^{{l'-1,-m'+1}}\frac{1}{\sqrt{2}}\partial_x\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{-m'+1,1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\frac{1}{2}f^{{l'+1,-m'+1}}\frac{i}{\sqrt{2}}\partial_x\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{-m'+1,-1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\frac{1}{2}f^{{l'+1,-m'+1}}\frac{i}{\sqrt{2}}\partial_x\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{-m'+1,1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\frac{1}{2}f^{{l'+1,-m'+1}}\partial_x\left(L^{{0,0}}\left (\vec{x} \right )\delta_{l'+1,0}\delta_{-m'+1,0}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\frac{1}{2}f^{{l'+1,-m'+1}}\partial_x\left(L^{{1,0}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{-m'+1,0}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\frac{1}{2}f^{{l'+1,-m'+1}}\frac{1}{\sqrt{2}}\partial_x\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{-m'+1,-1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\frac{1}{2}f^{{l'+1,-m'+1}}\frac{1}{\sqrt{2}}\partial_x\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{-m'+1,1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\frac{i}{2}c^{{l'-1,-m'-1}}\frac{i}{\sqrt{2}}\partial_y\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{-m'-1,-1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\frac{i}{2}c^{{l'-1,-m'-1}}\frac{i}{\sqrt{2}}\partial_y\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{-m'-1,1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\frac{i}{2}c^{{l'-1,-m'-1}}\partial_y\left(L^{{0,0}}\left (\vec{x} \right )\delta_{l'-1,0}\delta_{-m'-1,0}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\frac{i}{2}c^{{l'-1,-m'-1}}\partial_y\left(L^{{1,0}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{-m'-1,0}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\frac{i}{2}c^{{l'-1,-m'-1}}\frac{1}{\sqrt{2}}\partial_y\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{-m'-1,-1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\frac{i}{2}c^{{l'-1,-m'-1}}\frac{1}{\sqrt{2}}\partial_y\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{-m'-1,1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\frac{i}{2}d^{{l'+1,-m'-1}}\frac{i}{\sqrt{2}}\partial_y\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{-m'-1,-1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\frac{i}{2}d^{{l'+1,-m'-1}}\frac{i}{\sqrt{2}}\partial_y\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{-m'-1,1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\frac{i}{2}d^{{l'+1,-m'-1}}\partial_y\left(L^{{0,0}}\left (\vec{x} \right )\delta_{l'+1,0}\delta_{-m'-1,0}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\frac{i}{2}d^{{l'+1,-m'-1}}\partial_y\left(L^{{1,0}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{-m'-1,0}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\frac{i}{2}d^{{l'+1,-m'-1}}\frac{1}{\sqrt{2}}\partial_y\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{-m'-1,-1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\frac{i}{2}d^{{l'+1,-m'-1}}\frac{1}{\sqrt{2}}\partial_y\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{-m'-1,1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\frac{i}{2}e^{{l'-1,-m'+1}}\frac{i}{\sqrt{2}}\partial_y\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{-m'+1,-1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\frac{i}{2}e^{{l'-1,-m'+1}}\frac{i}{\sqrt{2}}\partial_y\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{-m'+1,1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\frac{i}{2}e^{{l'-1,-m'+1}}\partial_y\left(L^{{0,0}}\left (\vec{x} \right )\delta_{l'-1,0}\delta_{-m'+1,0}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\frac{i}{2}e^{{l'-1,-m'+1}}\partial_y\left(L^{{1,0}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{-m'+1,0}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\frac{i}{2}e^{{l'-1,-m'+1}}\frac{1}{\sqrt{2}}\partial_y\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{-m'+1,-1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\frac{i}{2}e^{{l'-1,-m'+1}}\frac{1}{\sqrt{2}}\partial_y\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{-m'+1,1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\frac{i}{2}f^{{l'+1,-m'+1}}\frac{i}{\sqrt{2}}\partial_y\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{-m'+1,-1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\frac{i}{2}f^{{l'+1,-m'+1}}\frac{i}{\sqrt{2}}\partial_y\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{-m'+1,1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\frac{i}{2}f^{{l'+1,-m'+1}}\partial_y\left(L^{{0,0}}\left (\vec{x} \right )\delta_{l'+1,0}\delta_{-m'+1,0}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\frac{i}{2}f^{{l'+1,-m'+1}}\partial_y\left(L^{{1,0}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{-m'+1,0}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}\frac{i}{2}f^{{l'+1,-m'+1}}\frac{1}{\sqrt{2}}\partial_y\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{-m'+1,-1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}\frac{i}{2}f^{{l'+1,-m'+1}}\frac{1}{\sqrt{2}}\partial_y\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{-m'+1,1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}a^{{l'-1,-m'}}\frac{i}{\sqrt{2}}\partial_z\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{-m',-1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}a^{{l'-1,-m'}}\frac{i}{\sqrt{2}}\partial_z\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{-m',1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}a^{{l'-1,-m'}}\partial_z\left(L^{{0,0}}\left (\vec{x} \right )\delta_{l'-1,0}\delta_{-m',0}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}a^{{l'-1,-m'}}\partial_z\left(L^{{1,0}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{-m',0}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}a^{{l'-1,-m'}}\frac{1}{\sqrt{2}}\partial_z\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{-m',-1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}a^{{l'-1,-m'}}\frac{1}{\sqrt{2}}\partial_z\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'-1,1}\delta_{-m',1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}b^{{l'+1,-m'}}\frac{i}{\sqrt{2}}\partial_z\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{-m',-1}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}b^{{l'+1,-m'}}\frac{i}{\sqrt{2}}\partial_z\left(L^{{1,-1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{-m',1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}b^{{l'+1,-m'}}\partial_z\left(L^{{0,0}}\left (\vec{x} \right )\delta_{l'+1,0}\delta_{-m',0}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}b^{{l'+1,-m'}}\partial_z\left(L^{{1,0}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{-m',0}\right)
# $$
# $$
# \frac{i}{\sqrt{2}}b^{{l'+1,-m'}}\frac{1}{\sqrt{2}}\partial_z\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{-m',-1}\right)
# $$
# $$
# -\frac{i}{\sqrt{2}}b^{{l'+1,-m'}}\frac{1}{\sqrt{2}}\partial_z\left(L^{{1,1}}\left (\vec{x} \right )\delta_{l'+1,1}\delta_{-m',1}\right)
# $$

# %% [markdown]
# l=0 m=0
#
# ------------------------------
# $$
# -0.408248290464\frac{i}{\sqrt{2}}\partial_xL^{{1,-1}}\left (\vec{x} \right )-0.408248290464\frac{1}{\sqrt{2}}\partial_xL^{{1,1}}\left (\vec{x} \right )+0.408248290464\frac{i}{\sqrt{2}}\partial_xL^{{1,-1}}\left (\vec{x} \right )-0.408248290464\frac{1}{\sqrt{2}}\partial_xL^{{1,1}}\left (\vec{x} \right )+0.408248290463863j\frac{i}{\sqrt{2}}\partial_yL^{{1,-1}}\left (\vec{x} \right )+0.408248290463863j\frac{1}{\sqrt{2}}\partial_yL^{{1,1}}\left (\vec{x} \right )+0.408248290463863j\frac{i}{\sqrt{2}}\partial_yL^{{1,-1}}\left (\vec{x} \right )-0.408248290463863j\frac{1}{\sqrt{2}}\partial_yL^{{1,1}}\left (\vec{x} \right )+0.57735026919\partial_zL^{{1,0}}\left (\vec{x} \right )
# $$
# l=1 m=-1
#
# ------------------------------
# $$
# -0.408248290464\frac{i}{\sqrt{2}}\partial_xL^{{0,0}}\left (\vec{x} \right )-0.408248290464j\frac{i}{\sqrt{2}}\partial_yL^{{0,0}}\left (\vec{x} \right )+0.408248290464\frac{i}{\sqrt{2}}\partial_xL^{{0,0}}\left (\vec{x} \right )-0.408248290463863j\frac{i}{\sqrt{2}}\partial_yL^{{0,0}}\left (\vec{x} \right )
# $$
# l=1 m=0
#
# ------------------------------
# $$
# 0.57735026919\partial_zL^{{0,0}}\left (\vec{x} \right )
# $$
# l=1 m=1
#
# ------------------------------
# $$
# -0.408248290464\frac{1}{\sqrt{2}}\partial_xL^{{0,0}}\left (\vec{x} \right )-0.408248290464j\frac{1}{\sqrt{2}}\partial_yL^{{0,0}}\left (\vec{x} \right )+0.408248290464\frac{1}{\sqrt{2}}\partial_xL^{{0,0}}\left (\vec{x} \right )+0.408248290463863j\frac{1}{\sqrt{2}}\partial_yL^{{0,0}}\left (\vec{x} \right )
# $$
