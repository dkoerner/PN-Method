# %% [markdown]
# ----------------------------
#
# $$
# -\omega \cdot\left[\begin{array}\ \partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\\\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\\\partial_z\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\\\end{array}\right]
# $$
#
# ----------------------------
#
# $$
# \int{\overline{Y^{l', m'}}(\omega )\left(-\omega \cdot\left[\begin{array}\ \partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\\\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\\\partial_z\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\\\end{array}\right]\right)\mathbf{d}\omega}
# $$
#
# ----------------------------
#
# $$
# -\int{\overline{Y^{l', m'}}(\omega )\omega \cdot\left[\begin{array}\ \partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\\\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\\\partial_z\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\\\end{array}\right]\mathbf{d}\omega}
# $$
#
# ----------------------------
#
# $$
# -\int{\overline{Y^{l', m'}}(\omega )\left(\omega_{x}\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)+\omega_{y}\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)+\omega_{z}\partial_z\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\right)\mathbf{d}\omega}
# $$
#
# ----------------------------
#
# $$
# -\int{\overline{Y^{l', m'}}(\omega )\omega_{x}\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)+\overline{Y^{l', m'}}(\omega )\omega_{y}\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)+\overline{Y^{l', m'}}(\omega )\omega_{z}\partial_z\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\mathbf{d}\omega}
# $$
#
# ----------------------------
#
# $$
# -\left(\int{\overline{Y^{l', m'}}(\omega )\omega_{x}\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\mathbf{d}\omega}+\int{\overline{Y^{l', m'}}(\omega )\omega_{y}\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\mathbf{d}\omega}+\int{\overline{Y^{l', m'}}(\omega )\omega_{z}\partial_z\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\mathbf{d}\omega}\right)
# $$
#
# ----------------------------
#
# $$
# -\int{\overline{Y^{l', m'}}(\omega )\omega_{x}\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\mathbf{d}\omega}-\int{\overline{Y^{l', m'}}(\omega )\omega_{y}\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\mathbf{d}\omega}-\int{\overline{Y^{l', m'}}(\omega )\omega_{z}\partial_z\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\mathbf{d}\omega}
# $$
#
# ----------------------------
#
# $$
# -\partial_x\left(\int{\overline{Y^{l', m'}}(\omega )\omega_{x}\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\mathbf{d}\omega}\right)-\partial_y\left(\int{\overline{Y^{l', m'}}(\omega )\omega_{y}\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\mathbf{d}\omega}\right)-\partial_z\left(\int{\overline{Y^{l', m'}}(\omega )\omega_{z}\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\mathbf{d}\omega}\right)
# $$
#
# ----------------------------
#
# $$
# -\partial_x\left(\sum_{l=0}^{\infty}{\int{\overline{Y^{l', m'}}(\omega )\omega_{x}\left(\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)\mathbf{d}\omega}}\right)-\partial_y\left(\sum_{l=0}^{\infty}{\int{\overline{Y^{l', m'}}(\omega )\omega_{y}\left(\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)\mathbf{d}\omega}}\right)-\partial_z\left(\sum_{l=0}^{\infty}{\int{\overline{Y^{l', m'}}(\omega )\omega_{z}\left(\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)\mathbf{d}\omega}}\right)
# $$
#
# ----------------------------
#
# $$
# -\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\int{\overline{Y^{l', m'}}(\omega )\omega_{x}\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )\mathbf{d}\omega}}}\right)-\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\int{\overline{Y^{l', m'}}(\omega )\omega_{y}\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )\mathbf{d}\omega}}}\right)-\partial_z\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\int{\overline{Y^{l', m'}}(\omega )\omega_{z}\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )\mathbf{d}\omega}}}\right)
# $$
#
# ----------------------------
#
# $$
# -\partial_x\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\int{\overline{Y^{l', m'}}(\omega )\omega_{x}Y^{l, m}(\omega )\mathbf{d}\omega}}\right)}\right)-\partial_y\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\int{\overline{Y^{l', m'}}(\omega )\omega_{y}Y^{l, m}(\omega )\mathbf{d}\omega}}\right)}\right)-\partial_z\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\int{\overline{Y^{l', m'}}(\omega )\omega_{z}Y^{l, m}(\omega )\mathbf{d}\omega}}\right)}\right)
# $$
#
# ----------------------------
#
# $$
# -\partial_x\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\int{\frac{1}{2}\left(-c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )+d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )+e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )-f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\right)Y^{l, m}(\omega )\mathbf{d}\omega}}\right)}\right)-\partial_y\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\int{\frac{i}{2}\left(c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )-d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )+e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )-f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\right)Y^{l, m}(\omega )\mathbf{d}\omega}}\right)}\right)-\partial_z\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\int{\left(a^{{l'-1,m'}}\overline{Y^{l'-1, m'}}(\omega )+b^{{l'+1,m'}}\overline{Y^{l'+1, m'}}(\omega )\right)Y^{l, m}(\omega )\mathbf{d}\omega}}\right)}\right)
# $$
#
# ----------------------------
#
# $$
# -\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\int{\frac{1}{2}Y^{l, m}(\omega )\left(-c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )\right)+\frac{1}{2}Y^{l, m}(\omega )d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )+\frac{1}{2}Y^{l, m}(\omega )e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )+\frac{1}{2}Y^{l, m}(\omega )\left(-f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\right)\mathbf{d}\omega}}}\right)-\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\int{\frac{i}{2}Y^{l, m}(\omega )c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )+\frac{i}{2}Y^{l, m}(\omega )\left(-d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )\right)+\frac{i}{2}Y^{l, m}(\omega )e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )+\frac{i}{2}Y^{l, m}(\omega )\left(-f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\right)\mathbf{d}\omega}}}\right)-\partial_z\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\int{a^{{l'-1,m'}}\overline{Y^{l'-1, m'}}(\omega )Y^{l, m}(\omega )+b^{{l'+1,m'}}\overline{Y^{l'+1, m'}}(\omega )Y^{l, m}(\omega )\mathbf{d}\omega}}}\right)
# $$
#
# ----------------------------
#
# $$
# -\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\left(\int{\frac{1}{2}Y^{l, m}(\omega )\left(-c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )\right)\mathbf{d}\omega}+\int{\frac{1}{2}Y^{l, m}(\omega )d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )\mathbf{d}\omega}+\int{\frac{1}{2}Y^{l, m}(\omega )e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )\mathbf{d}\omega}+\int{\frac{1}{2}Y^{l, m}(\omega )\left(-f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\right)\mathbf{d}\omega}\right)}}\right)-\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\left(\int{\frac{i}{2}Y^{l, m}(\omega )c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{2}Y^{l, m}(\omega )\left(-d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )\right)\mathbf{d}\omega}+\int{\frac{i}{2}Y^{l, m}(\omega )e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{2}Y^{l, m}(\omega )\left(-f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\right)\mathbf{d}\omega}\right)}}\right)-\partial_z\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\left(\int{a^{{l'-1,m'}}\overline{Y^{l'-1, m'}}(\omega )Y^{l, m}(\omega )\mathbf{d}\omega}+\int{b^{{l'+1,m'}}\overline{Y^{l'+1, m'}}(\omega )Y^{l, m}(\omega )\mathbf{d}\omega}\right)}}\right)
# $$
#
# ----------------------------
#
# $$
# -\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\left(-\int{\frac{1}{2}Y^{l, m}(\omega )c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}+\int{\frac{1}{2}Y^{l, m}(\omega )d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )\mathbf{d}\omega}+\int{\frac{1}{2}Y^{l, m}(\omega )e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )\mathbf{d}\omega}-\int{\frac{1}{2}Y^{l, m}(\omega )f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\mathbf{d}\omega}\right)}}\right)-\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\left(\int{\frac{i}{2}Y^{l, m}(\omega )c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}-\int{\frac{i}{2}Y^{l, m}(\omega )d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{2}Y^{l, m}(\omega )e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )\mathbf{d}\omega}-\int{\frac{i}{2}Y^{l, m}(\omega )f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\mathbf{d}\omega}\right)}}\right)-\partial_z\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\left(\int{a^{{l'-1,m'}}\overline{Y^{l'-1, m'}}(\omega )Y^{l, m}(\omega )\mathbf{d}\omega}+\int{b^{{l'+1,m'}}\overline{Y^{l'+1, m'}}(\omega )Y^{l, m}(\omega )\mathbf{d}\omega}\right)}}\right)
# $$
#
# ----------------------------
#
# $$
# -\partial_x\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\left(-\frac{1}{2}c^{{l'-1,m'-1}}\int{Y^{l, m}(\omega )\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}+\frac{1}{2}d^{{l'+1,m'-1}}\int{Y^{l, m}(\omega )\overline{Y^{l'+1, m'-1}}(\omega )\mathbf{d}\omega}+\frac{1}{2}e^{{l'-1,m'+1}}\int{Y^{l, m}(\omega )\overline{Y^{l'-1, m'+1}}(\omega )\mathbf{d}\omega}-\frac{1}{2}f^{{l'+1,m'+1}}\int{Y^{l, m}(\omega )\overline{Y^{l'+1, m'+1}}(\omega )\mathbf{d}\omega}\right)}\right)}\right)-\partial_y\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\left(\frac{i}{2}c^{{l'-1,m'-1}}\int{Y^{l, m}(\omega )\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}-\frac{i}{2}d^{{l'+1,m'-1}}\int{Y^{l, m}(\omega )\overline{Y^{l'+1, m'-1}}(\omega )\mathbf{d}\omega}+\frac{i}{2}e^{{l'-1,m'+1}}\int{Y^{l, m}(\omega )\overline{Y^{l'-1, m'+1}}(\omega )\mathbf{d}\omega}-\frac{i}{2}f^{{l'+1,m'+1}}\int{Y^{l, m}(\omega )\overline{Y^{l'+1, m'+1}}(\omega )\mathbf{d}\omega}\right)}\right)}\right)-\partial_z\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\left(a^{{l'-1,m'}}\int{\overline{Y^{l'-1, m'}}(\omega )Y^{l, m}(\omega )\mathbf{d}\omega}+b^{{l'+1,m'}}\int{\overline{Y^{l'+1, m'}}(\omega )Y^{l, m}(\omega )\mathbf{d}\omega}\right)}\right)}\right)
# $$
#
# ----------------------------
#
# $$
# -\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(L^{{l,m}}\left (\vec{x} \right )\left(-\frac{1}{2}c^{{l'-1,m'-1}}\int{Y^{l, m}(\omega )\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}\right)+L^{{l,m}}\left (\vec{x} \right )\frac{1}{2}d^{{l'+1,m'-1}}\int{Y^{l, m}(\omega )\overline{Y^{l'+1, m'-1}}(\omega )\mathbf{d}\omega}+L^{{l,m}}\left (\vec{x} \right )\frac{1}{2}e^{{l'-1,m'+1}}\int{Y^{l, m}(\omega )\overline{Y^{l'-1, m'+1}}(\omega )\mathbf{d}\omega}+L^{{l,m}}\left (\vec{x} \right )\left(-\frac{1}{2}f^{{l'+1,m'+1}}\int{Y^{l, m}(\omega )\overline{Y^{l'+1, m'+1}}(\omega )\mathbf{d}\omega}\right)\right)}}\right)-\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(L^{{l,m}}\left (\vec{x} \right )\frac{i}{2}c^{{l'-1,m'-1}}\int{Y^{l, m}(\omega )\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}+L^{{l,m}}\left (\vec{x} \right )\left(-\frac{i}{2}d^{{l'+1,m'-1}}\int{Y^{l, m}(\omega )\overline{Y^{l'+1, m'-1}}(\omega )\mathbf{d}\omega}\right)+L^{{l,m}}\left (\vec{x} \right )\frac{i}{2}e^{{l'-1,m'+1}}\int{Y^{l, m}(\omega )\overline{Y^{l'-1, m'+1}}(\omega )\mathbf{d}\omega}+L^{{l,m}}\left (\vec{x} \right )\left(-\frac{i}{2}f^{{l'+1,m'+1}}\int{Y^{l, m}(\omega )\overline{Y^{l'+1, m'+1}}(\omega )\mathbf{d}\omega}\right)\right)}}\right)-\partial_z\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(L^{{l,m}}\left (\vec{x} \right )a^{{l'-1,m'}}\int{\overline{Y^{l'-1, m'}}(\omega )Y^{l, m}(\omega )\mathbf{d}\omega}+L^{{l,m}}\left (\vec{x} \right )b^{{l'+1,m'}}\int{\overline{Y^{l'+1, m'}}(\omega )Y^{l, m}(\omega )\mathbf{d}\omega}\right)}}\right)
# $$
#
# ----------------------------
#
# $$
# -\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(L^{{l,m}}\left (\vec{x} \right )\left(-\frac{1}{2}c^{{l'-1,m'-1}}\delta_{l,l'-1}\delta_{m,m'-1}\right)+L^{{l,m}}\left (\vec{x} \right )\frac{1}{2}d^{{l'+1,m'-1}}\delta_{l,l'+1}\delta_{m,m'-1}+L^{{l,m}}\left (\vec{x} \right )\frac{1}{2}e^{{l'-1,m'+1}}\delta_{l,l'-1}\delta_{m,m'+1}+L^{{l,m}}\left (\vec{x} \right )\left(-\frac{1}{2}f^{{l'+1,m'+1}}\delta_{l,l'+1}\delta_{m,m'+1}\right)\right)}}\right)-\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(L^{{l,m}}\left (\vec{x} \right )\frac{i}{2}c^{{l'-1,m'-1}}\delta_{l,l'-1}\delta_{m,m'-1}+L^{{l,m}}\left (\vec{x} \right )\left(-\frac{i}{2}d^{{l'+1,m'-1}}\delta_{l,l'+1}\delta_{m,m'-1}\right)+L^{{l,m}}\left (\vec{x} \right )\frac{i}{2}e^{{l'-1,m'+1}}\delta_{l,l'-1}\delta_{m,m'+1}+L^{{l,m}}\left (\vec{x} \right )\left(-\frac{i}{2}f^{{l'+1,m'+1}}\delta_{l,l'+1}\delta_{m,m'+1}\right)\right)}}\right)-\partial_z\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(L^{{l,m}}\left (\vec{x} \right )a^{{l'-1,m'}}\delta_{l'-1,l}\delta_{m',m}+L^{{l,m}}\left (\vec{x} \right )b^{{l'+1,m'}}\delta_{l'+1,l}\delta_{m',m}\right)}}\right)
# $$
#
# ----------------------------
#
# $$
# -\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\left(-\frac{1}{2}c^{{l'-1,m'-1}}\delta_{l,l'-1}\delta_{m,m'-1}\right)+\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{1}{2}d^{{l'+1,m'-1}}\delta_{l,l'+1}\delta_{m,m'-1}+\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{1}{2}e^{{l'-1,m'+1}}\delta_{l,l'-1}\delta_{m,m'+1}+\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\left(-\frac{1}{2}f^{{l'+1,m'+1}}\delta_{l,l'+1}\delta_{m,m'+1}\right)}}\right)-\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{i}{2}c^{{l'-1,m'-1}}\delta_{l,l'-1}\delta_{m,m'-1}+\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\left(-\frac{i}{2}d^{{l'+1,m'-1}}\delta_{l,l'+1}\delta_{m,m'-1}\right)+\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{i}{2}e^{{l'-1,m'+1}}\delta_{l,l'-1}\delta_{m,m'+1}+\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\left(-\frac{i}{2}f^{{l'+1,m'+1}}\delta_{l,l'+1}\delta_{m,m'+1}\right)}}\right)-\partial_z\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )a^{{l'-1,m'}}\delta_{l'-1,l}\delta_{m',m}+\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )b^{{l'+1,m'}}\delta_{l'+1,l}\delta_{m',m}}}\right)
# $$
#
# ----------------------------
#
# $$
# -\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{-\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{1}{2}c^{{l'-1,m'-1}}\delta_{l,l'-1}\delta_{m,m'-1}+\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{1}{2}d^{{l'+1,m'-1}}\delta_{l,l'+1}\delta_{m,m'-1}+\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{1}{2}e^{{l'-1,m'+1}}\delta_{l,l'-1}\delta_{m,m'+1}-\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{1}{2}f^{{l'+1,m'+1}}\delta_{l,l'+1}\delta_{m,m'+1}}}\right)-\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{i}{2}c^{{l'-1,m'-1}}\delta_{l,l'-1}\delta_{m,m'-1}-\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{i}{2}d^{{l'+1,m'-1}}\delta_{l,l'+1}\delta_{m,m'-1}+\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{i}{2}e^{{l'-1,m'+1}}\delta_{l,l'-1}\delta_{m,m'+1}-\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{i}{2}f^{{l'+1,m'+1}}\delta_{l,l'+1}\delta_{m,m'+1}}}\right)-\partial_z\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )a^{{l'-1,m'}}\delta_{l'-1,l}\delta_{m',m}+\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )b^{{l'+1,m'}}\delta_{l'+1,l}\delta_{m',m}}}\right)
# $$
#
# ----------------------------
#
# $$
# -\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{-\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{1}{2}c^{{l'-1,m'-1}}\delta_{l,l'-1}\delta_{m,m'-1}}}+\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{1}{2}d^{{l'+1,m'-1}}\delta_{l,l'+1}\delta_{m,m'-1}}}+\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{1}{2}e^{{l'-1,m'+1}}\delta_{l,l'-1}\delta_{m,m'+1}}}+\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{-\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{1}{2}f^{{l'+1,m'+1}}\delta_{l,l'+1}\delta_{m,m'+1}}}\right)-\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{i}{2}c^{{l'-1,m'-1}}\delta_{l,l'-1}\delta_{m,m'-1}}}+\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{-\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{i}{2}d^{{l'+1,m'-1}}\delta_{l,l'+1}\delta_{m,m'-1}}}+\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{i}{2}e^{{l'-1,m'+1}}\delta_{l,l'-1}\delta_{m,m'+1}}}+\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{-\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{i}{2}f^{{l'+1,m'+1}}\delta_{l,l'+1}\delta_{m,m'+1}}}\right)-\partial_z\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )a^{{l'-1,m'}}\delta_{l'-1,l}\delta_{m',m}}}+\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )b^{{l'+1,m'}}\delta_{l'+1,l}\delta_{m',m}}}\right)
# $$
#
# ----------------------------
#
# $$
# -\partial_x\left(-\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{1}{2}c^{{l'-1,m'-1}}\delta_{l,l'-1}\delta_{m,m'-1}}}+\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{1}{2}d^{{l'+1,m'-1}}\delta_{l,l'+1}\delta_{m,m'-1}}}+\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{1}{2}e^{{l'-1,m'+1}}\delta_{l,l'-1}\delta_{m,m'+1}}}-\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{1}{2}f^{{l'+1,m'+1}}\delta_{l,l'+1}\delta_{m,m'+1}}}\right)-\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{i}{2}c^{{l'-1,m'-1}}\delta_{l,l'-1}\delta_{m,m'-1}}}-\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{i}{2}d^{{l'+1,m'-1}}\delta_{l,l'+1}\delta_{m,m'-1}}}+\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{i}{2}e^{{l'-1,m'+1}}\delta_{l,l'-1}\delta_{m,m'+1}}}-\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )\frac{i}{2}f^{{l'+1,m'+1}}\delta_{l,l'+1}\delta_{m,m'+1}}}\right)-\partial_z\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )a^{{l'-1,m'}}\delta_{l'-1,l}\delta_{m',m}}}+\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )b^{{l'+1,m'}}\delta_{l'+1,l}\delta_{m',m}}}\right)
# $$
#
# ----------------------------
#
# $$
# -\partial_x\left(-\lambda_{{l'-1}}f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )\frac{1}{2}c^{{l'-1,m'-1}}+\lambda_{{l'+1}}f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )\frac{1}{2}d^{{l'+1,m'-1}}+\lambda_{{l'-1}}f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )\frac{1}{2}e^{{l'-1,m'+1}}-\lambda_{{l'+1}}f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )\frac{1}{2}f^{{l'+1,m'+1}}\right)-\partial_y\left(\lambda_{{l'-1}}f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )\frac{i}{2}c^{{l'-1,m'-1}}-\lambda_{{l'+1}}f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )\frac{i}{2}d^{{l'+1,m'-1}}+\lambda_{{l'-1}}f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )\frac{i}{2}e^{{l'-1,m'+1}}-\lambda_{{l'+1}}f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )\frac{i}{2}f^{{l'+1,m'+1}}\right)-\partial_z\left(\lambda_{{l'-1}}f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'}}\left (\vec{x} \right )a^{{l'-1,m'}}+\lambda_{{l'+1}}f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'}}\left (\vec{x} \right )b^{{l'+1,m'}}\right)
# $$
#
# ----------------------------
#
# $$
# -\left(-\left(\partial_x\left(-\lambda_{{l'-1}}f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )\frac{1}{2}c^{{l'-1,m'-1}}\right)+\partial_x\left(\lambda_{{l'+1}}f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )\frac{1}{2}d^{{l'+1,m'-1}}\right)+\partial_x\left(\lambda_{{l'-1}}f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )\frac{1}{2}e^{{l'-1,m'+1}}\right)+\partial_x\left(-\lambda_{{l'+1}}f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )\frac{1}{2}f^{{l'+1,m'+1}}\right)\right)\right)-\left(-\left(\partial_x\left(-\lambda_{{l'-1}}f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )\frac{1}{2}c^{{l'-1,m'-1}}\right)+\partial_x\left(\lambda_{{l'+1}}f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )\frac{1}{2}d^{{l'+1,m'-1}}\right)+\partial_x\left(\lambda_{{l'-1}}f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )\frac{1}{2}e^{{l'-1,m'+1}}\right)+\partial_x\left(-\lambda_{{l'+1}}f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )\frac{1}{2}f^{{l'+1,m'+1}}\right)\right)\right)-\left(-\left(\partial_x\left(-\lambda_{{l'-1}}f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )\frac{1}{2}c^{{l'-1,m'-1}}\right)+\partial_x\left(\lambda_{{l'+1}}f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )\frac{1}{2}d^{{l'+1,m'-1}}\right)+\partial_x\left(\lambda_{{l'-1}}f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )\frac{1}{2}e^{{l'-1,m'+1}}\right)+\partial_x\left(-\lambda_{{l'+1}}f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )\frac{1}{2}f^{{l'+1,m'+1}}\right)\right)\right)
# $$
#
# ----------------------------
#
# $$
# \partial_x\left(\lambda_{{l'-1}}f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )\frac{1}{2}c^{{l'-1,m'-1}}\right)-\partial_x\left(\lambda_{{l'+1}}f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )\frac{1}{2}d^{{l'+1,m'-1}}\right)-\partial_x\left(\lambda_{{l'-1}}f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )\frac{1}{2}e^{{l'-1,m'+1}}\right)+\partial_x\left(\lambda_{{l'+1}}f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )\frac{1}{2}f^{{l'+1,m'+1}}\right)-\partial_y\left(\lambda_{{l'-1}}f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )\frac{i}{2}c^{{l'-1,m'-1}}\right)+\partial_y\left(\lambda_{{l'+1}}f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )\frac{i}{2}d^{{l'+1,m'-1}}\right)-\partial_y\left(\lambda_{{l'-1}}f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )\frac{i}{2}e^{{l'-1,m'+1}}\right)+\partial_y\left(\lambda_{{l'+1}}f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )\frac{i}{2}f^{{l'+1,m'+1}}\right)-\partial_z\left(\lambda_{{l'-1}}f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'}}\left (\vec{x} \right )a^{{l'-1,m'}}\right)-\partial_z\left(\lambda_{{l'+1}}f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'}}\left (\vec{x} \right )b^{{l'+1,m'}}\right)
# $$
#
# ----------------------------
#
# $$
# \lambda_{{l'-1}}\frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )\right)-\lambda_{{l'+1}}\frac{1}{2}d^{{l'+1,m'-1}}\partial_x\left(f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )\right)-\lambda_{{l'-1}}\frac{1}{2}e^{{l'-1,m'+1}}\partial_x\left(f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )\right)+\lambda_{{l'+1}}\frac{1}{2}f^{{l'+1,m'+1}}\partial_x\left(f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )\right)-\lambda_{{l'-1}}\frac{i}{2}c^{{l'-1,m'-1}}\partial_y\left(f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )\right)+\lambda_{{l'+1}}\frac{i}{2}d^{{l'+1,m'-1}}\partial_y\left(f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )\right)-\lambda_{{l'-1}}\frac{i}{2}e^{{l'-1,m'+1}}\partial_y\left(f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )\right)+\lambda_{{l'+1}}\frac{i}{2}f^{{l'+1,m'+1}}\partial_y\left(f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )\right)-\lambda_{{l'-1}}a^{{l'-1,m'}}\partial_z\left(f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'}}\left (\vec{x} \right )\right)-\lambda_{{l'+1}}b^{{l'+1,m'}}\partial_z\left(f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'}}\left (\vec{x} \right )\right)
# $$

# %% [markdown]
# ----------------------------
#
# $$
# -\frac{1}{2}c^{{l'-1,m'-1}}\int{\partial_x\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)}\right)\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}+\frac{1}{2}d^{{l'+1,m'-1}}\int{\partial_x\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)}\right)\overline{Y^{l'+1, m'-1}}(\omega )\mathbf{d}\omega}+\frac{1}{2}e^{{l'-1,m'+1}}\int{\partial_x\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)}\right)\overline{Y^{l'-1, m'+1}}(\omega )\mathbf{d}\omega}-\frac{1}{2}f^{{l'+1,m'+1}}\int{\partial_x\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)}\right)\overline{Y^{l'+1, m'+1}}(\omega )\mathbf{d}\omega}+\frac{i}{2}c^{{l'-1,m'-1}}\int{\partial_y\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)}\right)\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}-\frac{i}{2}d^{{l'+1,m'-1}}\int{\partial_y\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)}\right)\overline{Y^{l'+1, m'-1}}(\omega )\mathbf{d}\omega}+\frac{i}{2}e^{{l'-1,m'+1}}\int{\partial_y\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)}\right)\overline{Y^{l'-1, m'+1}}(\omega )\mathbf{d}\omega}-\frac{i}{2}f^{{l'+1,m'+1}}\int{\partial_y\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)}\right)\overline{Y^{l'+1, m'+1}}(\omega )\mathbf{d}\omega}+a^{{l'-1,m'}}\int{\overline{Y^{l'-1, m'}}(\omega )\partial_z\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)}\right)\mathbf{d}\omega}+b^{{l'+1,m'}}\int{\overline{Y^{l'+1, m'}}(\omega )\partial_z\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)}\right)\mathbf{d}\omega}
# $$
