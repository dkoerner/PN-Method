# %% [markdown]
# $$
# -\left(\omega\cdot\nabla\right)\left(\sigma_s\int_{\Omega'}f_p\left(\omega'\rightarrow\omega\right)L\mathbf{d}\omega'\right)
# $$

# %% [markdown]
# ----------------------------
#
# $$
# \left(-\omega \right)\cdot\nabla{\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\right)}
# $$
#
# ----------------------------
#
# $$
# \int{\overline{Y^{l', m'}}(\omega )\left(-\omega \right)\cdot\nabla{\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\right)}\mathbf{d}\omega}
# $$
#
# ----------------------------
#
# $$
# -\int{\overline{Y^{l', m'}}(\omega )\omega \cdot\nabla{\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\right)}\mathbf{d}\omega}
# $$
#
#
# ----------------------------
#
# $$
# -\int{\overline{Y^{l', m'}}(\omega )\left(\omega_{x}\partial_x\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\right)+\omega_{y}\partial_y\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\right)+\omega_{z}\partial_z\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\right)\right)\mathbf{d}\omega}
# $$
#
# ----------------------------
#
# $$
# -\int{\overline{Y^{l', m'}}(\omega )\omega_{x}\partial_x\left(\sum_{l=0}^{\infty}{\sigma_s\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)}\right)+\overline{Y^{l', m'}}(\omega )\omega_{y}\partial_y\left(\sum_{l=0}^{\infty}{\sigma_s\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)}\right)+\overline{Y^{l', m'}}(\omega )\omega_{z}\partial_z\left(\sum_{l=0}^{\infty}{\sigma_s\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)}\right)\mathbf{d}\omega}
# $$
#
#
# ----------------------------
#
# $$
# -\left(\int{\overline{Y^{l', m'}}(\omega )\omega_{x}\partial_x\left(\sum_{l=0}^{\infty}{\sigma_s\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)}\right)\mathbf{d}\omega}+\int{\overline{Y^{l', m'}}(\omega )\omega_{y}\partial_y\left(\sum_{l=0}^{\infty}{\sigma_s\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)}\right)\mathbf{d}\omega}+\int{\overline{Y^{l', m'}}(\omega )\omega_{z}\partial_z\left(\sum_{l=0}^{\infty}{\sigma_s\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)}\right)\mathbf{d}\omega}\right)
# $$
#
#
# ----------------------------
#
# $$
# -\int{\overline{Y^{l', m'}}(\omega )\omega_{x}\partial_x\left(\sum_{l=0}^{\infty}{\sigma_s\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)}\right)\mathbf{d}\omega}-\int{\overline{Y^{l', m'}}(\omega )\omega_{y}\partial_y\left(\sum_{l=0}^{\infty}{\sigma_s\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)}\right)\mathbf{d}\omega}-\int{\overline{Y^{l', m'}}(\omega )\omega_{z}\partial_z\left(\sum_{l=0}^{\infty}{\sigma_s\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)}\right)\mathbf{d}\omega}
# $$
#
# ----------------------------
#
# $$
# -\int{\frac{1}{2}\left(-c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )+d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )+e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )-f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\right)\partial_x\left(\sum_{l=0}^{\infty}{\sigma_s\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)}\right)\mathbf{d}\omega}-\int{\frac{i}{2}\left(c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )-d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )+e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )-f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\right)\partial_y\left(\sum_{l=0}^{\infty}{\sigma_s\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)}\right)\mathbf{d}\omega}-\int{\left(a^{{l'-1,m'}}\overline{Y^{l'-1, m'}}(\omega )+b^{{l'+1,m'}}\overline{Y^{l'+1, m'}}(\omega )\right)\partial_z\left(\sum_{l=0}^{\infty}{\sigma_s\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}\right)}\right)\mathbf{d}\omega}
# $$
#
#
#
# ----------------------------
#
# $$
# -\int{\frac{1}{2}\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\left(-c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )\right)+\frac{1}{2}\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )+\frac{1}{2}\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )+\frac{1}{2}\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\left(-f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\right)\mathbf{d}\omega}-\int{\frac{i}{2}\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )+\frac{i}{2}\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\left(-d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )\right)+\frac{i}{2}\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )+\frac{i}{2}\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\left(-f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\right)\mathbf{d}\omega}-\int{a^{{l'-1,m'}}\overline{Y^{l'-1, m'}}(\omega )\partial_z\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)+b^{{l'+1,m'}}\overline{Y^{l'+1, m'}}(\omega )\partial_z\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\mathbf{d}\omega}
# $$
#
#
#
# ----------------------------
#
# $$
# -\left(\int{\frac{1}{2}\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\left(-c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )\right)\mathbf{d}\omega}+\int{\frac{1}{2}\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )\mathbf{d}\omega}+\int{\frac{1}{2}\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )\mathbf{d}\omega}+\int{\frac{1}{2}\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\left(-f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\right)\mathbf{d}\omega}\right)-\left(\int{\frac{i}{2}\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{2}\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\left(-d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )\right)\mathbf{d}\omega}+\int{\frac{i}{2}\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{2}\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\left(-f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\right)\mathbf{d}\omega}\right)-\left(\int{a^{{l'-1,m'}}\overline{Y^{l'-1, m'}}(\omega )\partial_z\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\mathbf{d}\omega}+\int{b^{{l'+1,m'}}\overline{Y^{l'+1, m'}}(\omega )\partial_z\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\mathbf{d}\omega}\right)
# $$

# %% [markdown]
# ----------------------------
#
# $$
# \int{\frac{1}{2}\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}-\int{\frac{1}{2}\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )\mathbf{d}\omega}-\int{\frac{1}{2}\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )\mathbf{d}\omega}+\int{\frac{1}{2}\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\mathbf{d}\omega}-\int{\frac{i}{2}\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{2}\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )\mathbf{d}\omega}-\int{\frac{i}{2}\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )\mathbf{d}\omega}+\int{\frac{i}{2}\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\mathbf{d}\omega}-\int{a^{{l'-1,m'}}\overline{Y^{l'-1, m'}}(\omega )\partial_z\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\mathbf{d}\omega}-\int{b^{{l'+1,m'}}\overline{Y^{l'+1, m'}}(\omega )\partial_z\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )}}\right)\mathbf{d}\omega}
# $$
#
#
#
# ----------------------------
#
# $$
# \partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\int{\frac{1}{2}c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )\mathbf{d}\omega}}}\right)-\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\int{\frac{1}{2}d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )\mathbf{d}\omega}}}\right)-\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\int{\frac{1}{2}e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )\mathbf{d}\omega}}}\right)+\partial_x\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\int{\frac{1}{2}f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )\mathbf{d}\omega}}}\right)-\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\int{\frac{i}{2}c^{{l'-1,m'-1}}\overline{Y^{l'-1, m'-1}}(\omega )\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )\mathbf{d}\omega}}}\right)+\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\int{\frac{i}{2}d^{{l'+1,m'-1}}\overline{Y^{l'+1, m'-1}}(\omega )\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )\mathbf{d}\omega}}}\right)-\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\int{\frac{i}{2}e^{{l'-1,m'+1}}\overline{Y^{l'-1, m'+1}}(\omega )\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )\mathbf{d}\omega}}}\right)+\partial_y\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\int{\frac{i}{2}f^{{l'+1,m'+1}}\overline{Y^{l'+1, m'+1}}(\omega )\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )\mathbf{d}\omega}}}\right)-\partial_z\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\int{a^{{l'-1,m'}}\overline{Y^{l'-1, m'}}(\omega )\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )\mathbf{d}\omega}}}\right)-\partial_z\left(\sum_{l=0}^{\infty}{\sum_{m=-l}^{l}{\int{b^{{l'+1,m'}}\overline{Y^{l'+1, m'}}(\omega )\sigma_s\left (\vec{x} \right )\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )L^{{l,m}}\left (\vec{x} \right )Y^{l, m}(\omega )\mathbf{d}\omega}}}\right)
# $$
#
#
#
# ----------------------------
#
# $$
# \frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\int{\overline{Y^{l'-1, m'-1}}(\omega )Y^{l, m}(\omega )\mathbf{d}\omega}}\right)}\right)\right)-\frac{1}{2}d^{{l'+1,m'-1}}\partial_x\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\int{\overline{Y^{l'+1, m'-1}}(\omega )Y^{l, m}(\omega )\mathbf{d}\omega}}\right)}\right)\right)-\frac{1}{2}e^{{l'-1,m'+1}}\partial_x\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\int{\overline{Y^{l'-1, m'+1}}(\omega )Y^{l, m}(\omega )\mathbf{d}\omega}}\right)}\right)\right)+\frac{1}{2}f^{{l'+1,m'+1}}\partial_x\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\int{\overline{Y^{l'+1, m'+1}}(\omega )Y^{l, m}(\omega )\mathbf{d}\omega}}\right)}\right)\right)-\frac{i}{2}c^{{l'-1,m'-1}}\partial_y\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\int{\overline{Y^{l'-1, m'-1}}(\omega )Y^{l, m}(\omega )\mathbf{d}\omega}}\right)}\right)\right)+\frac{i}{2}d^{{l'+1,m'-1}}\partial_y\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\int{\overline{Y^{l'+1, m'-1}}(\omega )Y^{l, m}(\omega )\mathbf{d}\omega}}\right)}\right)\right)-\frac{i}{2}e^{{l'-1,m'+1}}\partial_y\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\int{\overline{Y^{l'-1, m'+1}}(\omega )Y^{l, m}(\omega )\mathbf{d}\omega}}\right)}\right)\right)+\frac{i}{2}f^{{l'+1,m'+1}}\partial_y\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\int{\overline{Y^{l'+1, m'+1}}(\omega )Y^{l, m}(\omega )\mathbf{d}\omega}}\right)}\right)\right)-a^{{l'-1,m'}}\partial_z\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\int{\overline{Y^{l'-1, m'}}(\omega )Y^{l, m}(\omega )\mathbf{d}\omega}}\right)}\right)\right)-b^{{l'+1,m'}}\partial_z\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\int{\overline{Y^{l'+1, m'}}(\omega )Y^{l, m}(\omega )\mathbf{d}\omega}}\right)}\right)\right)
# $$
#
#
#
# ----------------------------
#
# $$
# \frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\delta_{l'-1,l}\delta_{m'-1,m}}\right)}\right)\right)-\frac{1}{2}d^{{l'+1,m'-1}}\partial_x\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\delta_{l'+1,l}\delta_{m'-1,m}}\right)}\right)\right)-\frac{1}{2}e^{{l'-1,m'+1}}\partial_x\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\delta_{l'-1,l}\delta_{m'+1,m}}\right)}\right)\right)+\frac{1}{2}f^{{l'+1,m'+1}}\partial_x\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\delta_{l'+1,l}\delta_{m'+1,m}}\right)}\right)\right)-\frac{i}{2}c^{{l'-1,m'-1}}\partial_y\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\delta_{l'-1,l}\delta_{m'-1,m}}\right)}\right)\right)+\frac{i}{2}d^{{l'+1,m'-1}}\partial_y\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\delta_{l'+1,l}\delta_{m'-1,m}}\right)}\right)\right)-\frac{i}{2}e^{{l'-1,m'+1}}\partial_y\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\delta_{l'-1,l}\delta_{m'+1,m}}\right)}\right)\right)+\frac{i}{2}f^{{l'+1,m'+1}}\partial_y\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\delta_{l'+1,l}\delta_{m'+1,m}}\right)}\right)\right)-a^{{l'-1,m'}}\partial_z\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\delta_{l'-1,l}\delta_{m',m}}\right)}\right)\right)-b^{{l'+1,m'}}\partial_z\left(\sigma_s\left (\vec{x} \right )\left(\sum_{l=0}^{\infty}{\lambda_{{l}}f_p^{{l,0}}\left (\vec{x} \right )\left(\sum_{m=-l}^{l}{L^{{l,m}}\left (\vec{x} \right )\delta_{l'+1,l}\delta_{m',m}}\right)}\right)\right)
# $$
#
# ----------------------------
#
# $$
# \frac{1}{2}c^{{l'-1,m'-1}}\partial_x\left(\sigma_s\left (\vec{x} \right )\lambda_{{l'-1}}f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )\right)-\frac{1}{2}d^{{l'+1,m'-1}}\partial_x\left(\sigma_s\left (\vec{x} \right )\lambda_{{l'+1}}f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )\right)-\frac{1}{2}e^{{l'-1,m'+1}}\partial_x\left(\sigma_s\left (\vec{x} \right )\lambda_{{l'-1}}f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )\right)+\frac{1}{2}f^{{l'+1,m'+1}}\partial_x\left(\sigma_s\left (\vec{x} \right )\lambda_{{l'+1}}f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )\right)-\frac{i}{2}c^{{l'-1,m'-1}}\partial_y\left(\sigma_s\left (\vec{x} \right )\lambda_{{l'-1}}f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )\right)+\frac{i}{2}d^{{l'+1,m'-1}}\partial_y\left(\sigma_s\left (\vec{x} \right )\lambda_{{l'+1}}f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )\right)-\frac{i}{2}e^{{l'-1,m'+1}}\partial_y\left(\sigma_s\left (\vec{x} \right )\lambda_{{l'-1}}f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )\right)+\frac{i}{2}f^{{l'+1,m'+1}}\partial_y\left(\sigma_s\left (\vec{x} \right )\lambda_{{l'+1}}f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )\right)-a^{{l'-1,m'}}\partial_z\left(\sigma_s\left (\vec{x} \right )\lambda_{{l'-1}}f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'}}\left (\vec{x} \right )\right)-b^{{l'+1,m'}}\partial_z\left(\sigma_s\left (\vec{x} \right )\lambda_{{l'+1}}f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'}}\left (\vec{x} \right )\right)
# $$
#
#
# ----------------------------
#
# $$
# \frac{1}{2}c^{{l'-1,m'-1}}\lambda_{{l'-1}}\partial_x\left(\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )\right)-\frac{1}{2}d^{{l'+1,m'-1}}\lambda_{{l'+1}}\partial_x\left(\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )\right)-\frac{1}{2}e^{{l'-1,m'+1}}\lambda_{{l'-1}}\partial_x\left(\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )\right)+\frac{1}{2}f^{{l'+1,m'+1}}\lambda_{{l'+1}}\partial_x\left(\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )\right)-\frac{i}{2}c^{{l'-1,m'-1}}\lambda_{{l'-1}}\partial_y\left(\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )\right)+\frac{i}{2}d^{{l'+1,m'-1}}\lambda_{{l'+1}}\partial_y\left(\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )\right)-\frac{i}{2}e^{{l'-1,m'+1}}\lambda_{{l'-1}}\partial_y\left(\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )\right)+\frac{i}{2}f^{{l'+1,m'+1}}\lambda_{{l'+1}}\partial_y\left(\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )\right)-a^{{l'-1,m'}}\lambda_{{l'-1}}\partial_z\left(\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'}}\left (\vec{x} \right )\right)-b^{{l'+1,m'}}\lambda_{{l'+1}}\partial_z\left(\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'}}\left (\vec{x} \right )\right)
# $$
#
#
# ----------------------------
#
# $$
# \frac{1}{2}c^{{l'-1,m'-1}}\lambda_{{l'-1}}\left(\partial_x\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )+\sigma_s\left (\vec{x} \right )\partial_xf_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )+\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )\partial_xL^{{l'-1,m'-1}}\left (\vec{x} \right )\right)-\frac{1}{2}d^{{l'+1,m'-1}}\lambda_{{l'+1}}\left(\partial_x\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )+\sigma_s\left (\vec{x} \right )\partial_xf_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )+\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )\partial_xL^{{l'+1,m'-1}}\left (\vec{x} \right )\right)-\frac{1}{2}e^{{l'-1,m'+1}}\lambda_{{l'-1}}\left(\partial_x\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )+\sigma_s\left (\vec{x} \right )\partial_xf_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )+\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )\partial_xL^{{l'-1,m'+1}}\left (\vec{x} \right )\right)+\frac{1}{2}f^{{l'+1,m'+1}}\lambda_{{l'+1}}\left(\partial_x\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )+\sigma_s\left (\vec{x} \right )\partial_xf_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )+\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )\partial_xL^{{l'+1,m'+1}}\left (\vec{x} \right )\right)-\frac{i}{2}c^{{l'-1,m'-1}}\lambda_{{l'-1}}\left(\partial_y\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )+\sigma_s\left (\vec{x} \right )\partial_yf_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )+\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )\partial_yL^{{l'-1,m'-1}}\left (\vec{x} \right )\right)+\frac{i}{2}d^{{l'+1,m'-1}}\lambda_{{l'+1}}\left(\partial_y\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )+\sigma_s\left (\vec{x} \right )\partial_yf_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )+\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )\partial_yL^{{l'+1,m'-1}}\left (\vec{x} \right )\right)-\frac{i}{2}e^{{l'-1,m'+1}}\lambda_{{l'-1}}\left(\partial_y\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )+\sigma_s\left (\vec{x} \right )\partial_yf_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )+\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )\partial_yL^{{l'-1,m'+1}}\left (\vec{x} \right )\right)+\frac{i}{2}f^{{l'+1,m'+1}}\lambda_{{l'+1}}\left(\partial_y\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )+\sigma_s\left (\vec{x} \right )\partial_yf_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )+\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )\partial_yL^{{l'+1,m'+1}}\left (\vec{x} \right )\right)-a^{{l'-1,m'}}\lambda_{{l'-1}}\left(\partial_z\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'}}\left (\vec{x} \right )+\sigma_s\left (\vec{x} \right )\partial_zf_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'}}\left (\vec{x} \right )+\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )\partial_zL^{{l'-1,m'}}\left (\vec{x} \right )\right)-b^{{l'+1,m'}}\lambda_{{l'+1}}\left(\partial_z\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'}}\left (\vec{x} \right )+\sigma_s\left (\vec{x} \right )\partial_zf_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'}}\left (\vec{x} \right )+\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )\partial_zL^{{l'+1,m'}}\left (\vec{x} \right )\right)
# $$

# %% [markdown]
# ----------------------------
#
# $$
# \frac{1}{2}c^{{l'-1,m'-1}}\lambda_{{l'-1}}\partial_x\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )+\frac{1}{2}c^{{l'-1,m'-1}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )\partial_xf_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )+\frac{1}{2}c^{{l'-1,m'-1}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )\partial_xL^{{l'-1,m'-1}}\left (\vec{x} \right )-\left(\frac{1}{2}d^{{l'+1,m'-1}}\lambda_{{l'+1}}\partial_x\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )+\frac{1}{2}d^{{l'+1,m'-1}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )\partial_xf_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )+\frac{1}{2}d^{{l'+1,m'-1}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )\partial_xL^{{l'+1,m'-1}}\left (\vec{x} \right )\right)-\left(\frac{1}{2}e^{{l'-1,m'+1}}\lambda_{{l'-1}}\partial_x\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )+\frac{1}{2}e^{{l'-1,m'+1}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )\partial_xf_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )+\frac{1}{2}e^{{l'-1,m'+1}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )\partial_xL^{{l'-1,m'+1}}\left (\vec{x} \right )\right)+\frac{1}{2}f^{{l'+1,m'+1}}\lambda_{{l'+1}}\partial_x\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )+\frac{1}{2}f^{{l'+1,m'+1}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )\partial_xf_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )+\frac{1}{2}f^{{l'+1,m'+1}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )\partial_xL^{{l'+1,m'+1}}\left (\vec{x} \right )-\left(\frac{i}{2}c^{{l'-1,m'-1}}\lambda_{{l'-1}}\partial_y\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )+\frac{i}{2}c^{{l'-1,m'-1}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )\partial_yf_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )+\frac{i}{2}c^{{l'-1,m'-1}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )\partial_yL^{{l'-1,m'-1}}\left (\vec{x} \right )\right)+\frac{i}{2}d^{{l'+1,m'-1}}\lambda_{{l'+1}}\partial_y\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )+\frac{i}{2}d^{{l'+1,m'-1}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )\partial_yf_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )+\frac{i}{2}d^{{l'+1,m'-1}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )\partial_yL^{{l'+1,m'-1}}\left (\vec{x} \right )-\left(\frac{i}{2}e^{{l'-1,m'+1}}\lambda_{{l'-1}}\partial_y\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )+\frac{i}{2}e^{{l'-1,m'+1}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )\partial_yf_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )+\frac{i}{2}e^{{l'-1,m'+1}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )\partial_yL^{{l'-1,m'+1}}\left (\vec{x} \right )\right)+\frac{i}{2}f^{{l'+1,m'+1}}\lambda_{{l'+1}}\partial_y\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )+\frac{i}{2}f^{{l'+1,m'+1}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )\partial_yf_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )+\frac{i}{2}f^{{l'+1,m'+1}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )\partial_yL^{{l'+1,m'+1}}\left (\vec{x} \right )-\left(a^{{l'-1,m'}}\lambda_{{l'-1}}\partial_z\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'}}\left (\vec{x} \right )+a^{{l'-1,m'}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )\partial_zf_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'}}\left (\vec{x} \right )+a^{{l'-1,m'}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )\partial_zL^{{l'-1,m'}}\left (\vec{x} \right )\right)-\left(b^{{l'+1,m'}}\lambda_{{l'+1}}\partial_z\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'}}\left (\vec{x} \right )+b^{{l'+1,m'}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )\partial_zf_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'}}\left (\vec{x} \right )+b^{{l'+1,m'}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )\partial_zL^{{l'+1,m'}}\left (\vec{x} \right )\right)
# $$
#
#
#
# ----------------------------
#
# $$
# \frac{1}{2}c^{{l'-1,m'-1}}\lambda_{{l'-1}}\partial_x\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )+\frac{1}{2}c^{{l'-1,m'-1}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )\partial_xf_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )+\frac{1}{2}c^{{l'-1,m'-1}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )\partial_xL^{{l'-1,m'-1}}\left (\vec{x} \right )-\frac{1}{2}d^{{l'+1,m'-1}}\lambda_{{l'+1}}\partial_x\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )-\frac{1}{2}d^{{l'+1,m'-1}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )\partial_xf_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )-\frac{1}{2}d^{{l'+1,m'-1}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )\partial_xL^{{l'+1,m'-1}}\left (\vec{x} \right )-\frac{1}{2}e^{{l'-1,m'+1}}\lambda_{{l'-1}}\partial_x\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )-\frac{1}{2}e^{{l'-1,m'+1}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )\partial_xf_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )-\frac{1}{2}e^{{l'-1,m'+1}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )\partial_xL^{{l'-1,m'+1}}\left (\vec{x} \right )+\frac{1}{2}f^{{l'+1,m'+1}}\lambda_{{l'+1}}\partial_x\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )+\frac{1}{2}f^{{l'+1,m'+1}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )\partial_xf_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )+\frac{1}{2}f^{{l'+1,m'+1}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )\partial_xL^{{l'+1,m'+1}}\left (\vec{x} \right )-\frac{i}{2}c^{{l'-1,m'-1}}\lambda_{{l'-1}}\partial_y\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )-\frac{i}{2}c^{{l'-1,m'-1}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )\partial_yf_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )-\frac{i}{2}c^{{l'-1,m'-1}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )\partial_yL^{{l'-1,m'-1}}\left (\vec{x} \right )+\frac{i}{2}d^{{l'+1,m'-1}}\lambda_{{l'+1}}\partial_y\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )+\frac{i}{2}d^{{l'+1,m'-1}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )\partial_yf_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )+\frac{i}{2}d^{{l'+1,m'-1}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )\partial_yL^{{l'+1,m'-1}}\left (\vec{x} \right )-\frac{i}{2}e^{{l'-1,m'+1}}\lambda_{{l'-1}}\partial_y\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )-\frac{i}{2}e^{{l'-1,m'+1}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )\partial_yf_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )-\frac{i}{2}e^{{l'-1,m'+1}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )\partial_yL^{{l'-1,m'+1}}\left (\vec{x} \right )+\frac{i}{2}f^{{l'+1,m'+1}}\lambda_{{l'+1}}\partial_y\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )+\frac{i}{2}f^{{l'+1,m'+1}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )\partial_yf_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )+\frac{i}{2}f^{{l'+1,m'+1}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )\partial_yL^{{l'+1,m'+1}}\left (\vec{x} \right )-a^{{l'-1,m'}}\lambda_{{l'-1}}\partial_z\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'}}\left (\vec{x} \right )-a^{{l'-1,m'}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )\partial_zf_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'}}\left (\vec{x} \right )-a^{{l'-1,m'}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )\partial_zL^{{l'-1,m'}}\left (\vec{x} \right )-b^{{l'+1,m'}}\lambda_{{l'+1}}\partial_z\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'}}\left (\vec{x} \right )-b^{{l'+1,m'}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )\partial_zf_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'}}\left (\vec{x} \right )-b^{{l'+1,m'}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )\partial_zL^{{l'+1,m'}}\left (\vec{x} \right )
# $$

# %% [markdown]
# ----------------------------
#
# $$
# -\frac{1}{2}c^{{l'-1,m'-1}}\lambda_{{l'-1}}\partial_x\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )-\frac{1}{2}c^{{l'-1,m'-1}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )\partial_xf_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )-\frac{1}{2}c^{{l'-1,m'-1}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )\partial_xL^{{l'-1,m'-1}}\left (\vec{x} \right )+\frac{1}{2}d^{{l'+1,m'-1}}\lambda_{{l'+1}}\partial_x\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )+\frac{1}{2}d^{{l'+1,m'-1}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )\partial_xf_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )+\frac{1}{2}d^{{l'+1,m'-1}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )\partial_xL^{{l'+1,m'-1}}\left (\vec{x} \right )+\frac{1}{2}e^{{l'-1,m'+1}}\lambda_{{l'-1}}\partial_x\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )+\frac{1}{2}e^{{l'-1,m'+1}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )\partial_xf_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )+\frac{1}{2}e^{{l'-1,m'+1}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )\partial_xL^{{l'-1,m'+1}}\left (\vec{x} \right )-\frac{1}{2}f^{{l'+1,m'+1}}\lambda_{{l'+1}}\partial_x\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )-\frac{1}{2}f^{{l'+1,m'+1}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )\partial_xf_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )-\frac{1}{2}f^{{l'+1,m'+1}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )\partial_xL^{{l'+1,m'+1}}\left (\vec{x} \right )+\frac{i}{2}c^{{l'-1,m'-1}}\lambda_{{l'-1}}\partial_y\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )+\frac{i}{2}c^{{l'-1,m'-1}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )\partial_yf_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'-1}}\left (\vec{x} \right )+\frac{i}{2}c^{{l'-1,m'-1}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )\partial_yL^{{l'-1,m'-1}}\left (\vec{x} \right )-\frac{i}{2}d^{{l'+1,m'-1}}\lambda_{{l'+1}}\partial_y\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )-\frac{i}{2}d^{{l'+1,m'-1}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )\partial_yf_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'-1}}\left (\vec{x} \right )-\frac{i}{2}d^{{l'+1,m'-1}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )\partial_yL^{{l'+1,m'-1}}\left (\vec{x} \right )+\frac{i}{2}e^{{l'-1,m'+1}}\lambda_{{l'-1}}\partial_y\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )+\frac{i}{2}e^{{l'-1,m'+1}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )\partial_yf_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'+1}}\left (\vec{x} \right )+\frac{i}{2}e^{{l'-1,m'+1}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )\partial_yL^{{l'-1,m'+1}}\left (\vec{x} \right )-\frac{i}{2}f^{{l'+1,m'+1}}\lambda_{{l'+1}}\partial_y\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )-\frac{i}{2}f^{{l'+1,m'+1}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )\partial_yf_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'+1}}\left (\vec{x} \right )-\frac{i}{2}f^{{l'+1,m'+1}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )\partial_yL^{{l'+1,m'+1}}\left (\vec{x} \right )+a^{{l'-1,m'}}\lambda_{{l'-1}}\partial_z\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'}}\left (\vec{x} \right )+a^{{l'-1,m'}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )\partial_zf_p^{{l'-1,0}}\left (\vec{x} \right )L^{{l'-1,m'}}\left (\vec{x} \right )+a^{{l'-1,m'}}\lambda_{{l'-1}}\sigma_s\left (\vec{x} \right )f_p^{{l'-1,0}}\left (\vec{x} \right )\partial_zL^{{l'-1,m'}}\left (\vec{x} \right )+b^{{l'+1,m'}}\lambda_{{l'+1}}\partial_z\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'}}\left (\vec{x} \right )+b^{{l'+1,m'}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )\partial_zf_p^{{l'+1,0}}\left (\vec{x} \right )L^{{l'+1,m'}}\left (\vec{x} \right )+b^{{l'+1,m'}}\lambda_{{l'+1}}\sigma_s\left (\vec{x} \right )f_p^{{l'+1,0}}\left (\vec{x} \right )\partial_zL^{{l'+1,m'}}\left (\vec{x} \right )
# $$
